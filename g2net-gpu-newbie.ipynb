# %% [markdown]
# - Basically a 1D CNN starter with bandpass. Filter size hard-coded from [https://www.kaggle.com/kit716/grav-wave-detection](https://www.kaggle.com/kit716/grav-wave-detection) which uses the simple architecture from https://journals.aps.org/prl/pdf/10.1103/PhysRevLett.120.141103
# - Added inference to @hidehisaarai1213 's PyTorch starter, iteration order changed from Y.Nakama's pipeline: "iter on loader first then load model" to "load model first then iter the loader"

# %% [markdown]
# ## Libraries

# %%
import os
import time
import math
import random
from pathlib import Path

import numpy as np
import pandas as pd
import scipy as sp
from scipy import signal
import tensorflow as tf  # for reading TFRecord Dataset
import tensorflow_datasets as tfds  # for making tf.data.Dataset to return numpy arrays
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
#from kaggle_datasets import KaggleDatasets
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from tqdm import tqdm
import os

# %%
SAVEDIR = Path("./")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## CFG

# %%
class CFG:
    debug = False
    print_freq = 1000
    num_workers = 4
    scheduler = "CosineAnnealingLR"
    model_name = "1dcnn"
    epochs = 5
    T_max = 3
    lr = 1e-4
    min_lr = 1e-7
    batch_size = 1024
    val_batch_size = 100
    weight_decay = 1e-5
    gradient_accumulation_steps = 1
    max_grad_norm = 1000
    seed = 42
    target_size = 1
    target_col = "target"
    n_fold = 5
    trn_fold = [0, 1, 2, 3]  # [0, 1, 2, 3, 4]
    train = True
    bandpass_params = dict(lf=20, 
                           hf=500)

# %% [markdown]
# ## Utils

# %%
# ====================================================
# Utils
# ====================================================
def get_score(y_true, y_pred):
    score = roc_auc_score(y_true, y_pred)
    return score


def init_logger(log_file=SAVEDIR / 'train.log'):
    from logging import getLogger, INFO, FileHandler,  Formatter,  StreamHandler
    logger = getLogger(__name__)
    logger.setLevel(INFO)
    handler1 = StreamHandler()
    handler1.setFormatter(Formatter("%(message)s"))
    handler2 = FileHandler(filename=log_file)
    handler2.setFormatter(Formatter("%(message)s"))
    logger.addHandler(handler1)
    logger.addHandler(handler2)
    return logger

LOGGER = init_logger()


def seed_torch(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

seed_torch(seed=CFG.seed)

# %% [markdown]
# ## TFRecord Loader
#
# This is the heart of this notebook. Instead of using PyTorch's Dataset and DataLoader, here I define custom Loader that reads samples from TFRecords.
#
# FYI, there's a library that does the same thing, but its implementation is not optimized, so it's slower.
#
# https://github.com/vahidk/tfrecord

# %%
gcs_paths = []
all_files = []
path = "./data1/train/"
n_trial = 0
#print(j)
for dirname, _, filenames in os.walk(path):
    for filename in filenames:
        #print(filename)
        #print(os.path.join(dirname, filename))
        gcs_path = os.path.join(dirname, filename)
        gcs_paths.append(gcs_path)
        print(gcs_path)
        all_files.extend(np.sort(np.array(tf.io.gfile.glob(gcs_path))))
            
    
print("train_files: ", len(all_files))
all_files = np.array(all_files)
# Out:
# ./data1/train/train0.tfrecords
# ./data1/train/train1.tfrecords
# ./data1/train/train10.tfrecords
# ./data1/train/train11.tfrecords
# ./data1/train/train12.tfrecords
# ./data1/train/train13.tfrecords
# ./data1/train/train14.tfrecords
# ./data1/train/train15.tfrecords
# ./data1/train/train16.tfrecords
# ./data1/train/train17.tfrecords
# ./data1/train/train18.tfrecords
# ./data1/train/train19.tfrecords
# ./data1/train/train2.tfrecords
# ./data1/train/train3.tfrecords
# ./data1/train/train4.tfrecords
# ./data1/train/train5.tfrecords
# ./data1/train/train6.tfrecords
# ./data1/train/train7.tfrecords
# ./data1/train/train8.tfrecords
# ./data1/train/train9.tfrecords
# train_files:  20

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
def count_data_items(fileids, train=True):
    """
    Count the number of samples.
    Each of the TFRecord datasets is designed to contain 28000 samples for train
    22500 for test.
    """
    sizes = 28000 if train else 22500
    return len(fileids) * sizes


AUTO = tf.data.experimental.AUTOTUNE

# %% [markdown]
# ## Bandpass
#
# Modified from various notebooks and https://www.kaggle.com/c/g2net-gravitational-wave-detection/discussion/261721#1458564

# %%
def bandpass(x, lf=20, hf=500, order=8, sr=2048):
    '''
    Cell 33 of https://www.gw-openscience.org/LVT151012data/LOSC_Event_tutorial_LVT151012.html
    https://scipy-cookbook.readthedocs.io/items/ButterworthBandpass.html
    '''
    sos = signal.butter(order, [lf, hf], btype="bandpass", output="sos", fs=sr)
    normalization = np.sqrt((hf - lf) / (sr / 2))
    if x.ndim ==2:
        for i in range(3):
            x[i] = signal.sosfilt(sos, x[i]) * normalization
    elif x.ndim == 3: # batch
        for i in range(x.shape[0]):
            for j in range(3):
                x[i, j] = signal.sosfilt(sos, x[i, j]) * normalization
    return x

# %%
def prepare_wave(wave):
    wave = tf.reshape(tf.io.decode_raw(wave, tf.float64), (3, 4096))
    normalized_waves = []
    scaling = tf.constant([1.5e-20, 1.5e-20, 0.5e-20], dtype=tf.float64)
    for i in range(3):
#         normalized_wave = wave[i] / tf.math.reduce_max(wave[i])
        normalized_wave = wave[i] / scaling[i]
        normalized_waves.append(normalized_wave)
    wave = tf.stack(normalized_waves, axis=0)
    wave = tf.cast(wave, tf.float32)
    return wave


def read_labeled_tfrecord(example):
    tfrec_format = {
        "wave": tf.io.FixedLenFeature([], tf.string),
        "wave_id": tf.io.FixedLenFeature([], tf.string),
        "target": tf.io.FixedLenFeature([], tf.int64)
    }
    example = tf.io.parse_single_example(example, tfrec_format)
    return prepare_wave(example["wave"]), tf.reshape(tf.cast(example["target"], tf.float32), [1]), example["wave_id"]


def read_unlabeled_tfrecord(example, return_image_id):
    tfrec_format = {
        "wave": tf.io.FixedLenFeature([], tf.string),
        "wave_id": tf.io.FixedLenFeature([], tf.string)
    }
    example = tf.io.parse_single_example(example, tfrec_format)
    return prepare_wave(example["wave"]), example["wave_id"] if return_image_id else 0


def get_dataset(files, batch_size=16, repeat=False, cache=False, 
                shuffle=False, labeled=True, return_image_ids=True):
    ds = tf.data.TFRecordDataset(files, num_parallel_reads=AUTO, compression_type="GZIP")
    if cache:
        # You'll need around 15GB RAM if you'd like to cache val dataset, and 50~60GB RAM for train dataset.
        ds = ds.cache()

    if repeat:
        ds = ds.repeat()

    if shuffle:
        ds = ds.shuffle(1024 * 2)
        opt = tf.data.Options()
        opt.experimental_deterministic = False
        ds = ds.with_options(opt)

    if labeled:
        ds = ds.map(read_labeled_tfrecord, num_parallel_calls=AUTO)
    else:
        ds = ds.map(lambda example: read_unlabeled_tfrecord(example, return_image_ids), num_parallel_calls=AUTO)

    ds = ds.batch(batch_size)
    ds = ds.prefetch(AUTO)
    return tfds.as_numpy(ds)

# %%
class TFRecordDataLoader:
    def __init__(self, files, batch_size=32, cache=False, train=True, 
                              repeat=False, shuffle=False, labeled=True, 
                              return_image_ids=True):
        self.ds = get_dataset(
            files, 
            batch_size=batch_size,
            cache=cache,
            repeat=repeat,
            shuffle=shuffle,
            labeled=labeled,
            return_image_ids=return_image_ids)
        
        self.num_examples = count_data_items(files, labeled)

        self.batch_size = batch_size
        self.labeled = labeled
        self.return_image_ids = return_image_ids
        self._iterator = None
    
    def __iter__(self):
        if self._iterator is None:
            self._iterator = iter(self.ds)
        else:
            self._reset()
        return self._iterator

    def _reset(self):
        self._iterator = iter(self.ds)

    def __next__(self):
        batch = next(self._iterator)
        return batch

    def __len__(self):
        n_batches = self.num_examples // self.batch_size
        if self.num_examples % self.batch_size == 0:
            return n_batches
        else:
            return n_batches + 1

# %% [markdown]
# ## MODEL

# %%
class CNN1d(nn.Module):
    """1D convolutional neural network. Classifier of the gravitational waves.
    Architecture from there https://journals.aps.org/prl/pdf/10.1103/PhysRevLett.120.141103
    """

    def __init__(self, debug=False):
        super().__init__()
        self.cnn1 = nn.Sequential(
            nn.Conv1d(3, 64, kernel_size=64),
            nn.BatchNorm1d(64),
            nn.ELU(),
        )
        self.cnn2 = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=32),
            nn.AvgPool1d(kernel_size=8),
            nn.BatchNorm1d(64),
            nn.ELU(),
        )
        self.cnn3 = nn.Sequential(
            nn.Conv1d(64, 128, kernel_size=32),
            nn.BatchNorm1d(128),
            nn.ELU(),
        )
        self.cnn4 = nn.Sequential(
            nn.Conv1d(128, 128, kernel_size=16),
            nn.AvgPool1d(kernel_size=6),
            nn.BatchNorm1d(128),
            nn.ELU(),
        )
        self.cnn5 = nn.Sequential(
            nn.Conv1d(128, 256, kernel_size=16),
            nn.BatchNorm1d(256),
            nn.ELU(),
        )
        self.cnn6 = nn.Sequential(
            nn.Conv1d(256, 256, kernel_size=16),
            nn.MaxPool1d(kernel_size=4),
            nn.BatchNorm1d(256),
            nn.ELU(),
        )
        self.fc1 = nn.Sequential(
            nn.Linear(256 * 11, 64),
            nn.BatchNorm1d(64),
            nn.Dropout(0.4),
            nn.ELU(),
        )
        self.fc2 = nn.Sequential(
            nn.Linear(64, 64),
            nn.BatchNorm1d(64),
            nn.Dropout(0.4),
            nn.ELU(),
        )
        self.fc3 = nn.Sequential(
            nn.Linear(64, 1),
        )
        self.debug = debug

    def forward(self, x, pos=None):
        x = self.cnn1(x)
        x = self.cnn2(x)
        x = self.cnn3(x)
        x = self.cnn4(x)
        x = self.cnn5(x)
        x = self.cnn6(x)
        x = x.flatten(start_dim=1)
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        return x

# %% [markdown]
# ## Helper functions

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))


def max_memory_allocated():
    MB = 1024.0 * 1024.0
    mem = torch.cuda.max_memory_allocated() / MB
    return f"{mem:.0f} MB"

# %% [markdown]
# ## Trainer

# %%
def train_fn(files, model, criterion, optimizer, epoch, scheduler, device):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    scores = AverageMeter()

    # switch to train mode
    model.train()
    start = end = time.time()
    global_step = 0

    train_loader = TFRecordDataLoader(
        files, batch_size=CFG.batch_size, 
        shuffle=True)
    for step, d in enumerate(train_loader):
        # measure data loading time
        data_time.update(time.time() - end)
        x = bandpass(d[0], **CFG.bandpass_params)
        x = torch.from_numpy(x).to(device)
        labels = torch.from_numpy(d[1]).to(device)

        batch_size = labels.size(0)
        y_preds = model(x)
        loss = criterion(y_preds.view(-1), labels.view(-1))
        # record loss
        losses.update(loss.item(), batch_size)
        if CFG.gradient_accumulation_steps > 1:
            loss = loss / CFG.gradient_accumulation_steps
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), CFG.max_grad_norm)
        if (step + 1) % CFG.gradient_accumulation_steps == 0:
            optimizer.step()
            optimizer.zero_grad()
            global_step += 1
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()
        print('Epoch: [{0}/{1}][{2}/{3}] '
              'Loss: {loss.val:.4f}({loss.avg:.4f}) '
              'Grad: {grad_norm:.4f}  '
              'LR: {lr:.6f}  '
              'Elapsed: {remain:s} '
              'Max mem: {mem:s}'
              .format(
               epoch+1, CFG.epochs, step, len(train_loader),
               loss=losses,
               grad_norm=grad_norm,
               lr=scheduler.get_last_lr()[0],
               remain=timeSince(start, float(step + 1) / len(train_loader)),
               mem=max_memory_allocated()))
    return losses.avg


def valid_fn(files, model, criterion, device):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    scores = AverageMeter()
    # switch to evaluation mode
    model.eval()
    filenames = []
    targets = []
    preds = []
    start = end = time.time()
    valid_loader = TFRecordDataLoader(
        files, batch_size=CFG.batch_size * 2, shuffle=False)
    for step, d in enumerate(valid_loader):
        # measure data loading time
        data_time.update(time.time() - end)
        
        targets.extend(d[1].reshape(-1).tolist())
        filenames.extend([f.decode("UTF-8") for f in d[2]])
        x = bandpass(d[0], **CFG.bandpass_params)
        x = torch.from_numpy(x).to(device)
        labels = torch.from_numpy(d[1]).to(device)

        batch_size = labels.size(0)
        # compute loss
        with torch.no_grad():
            y_preds = model(x)
        loss = criterion(y_preds.view(-1), labels.view(-1))
        losses.update(loss.item(), batch_size)

        preds.append(y_preds.sigmoid().to('cpu').numpy())
        if CFG.gradient_accumulation_steps > 1:
            loss = loss / CFG.gradient_accumulation_steps
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()
        print('EVAL: [{0}/{1}] '
              'Data {data_time.val:.3f} ({data_time.avg:.3f}) '
              'Elapsed {remain:s} '
              'Loss: {loss.val:.4f}({loss.avg:.4f}) '
              .format(
               step, len(valid_loader), batch_time=batch_time,
               data_time=data_time, loss=losses,
               remain=timeSince(start, float(step+1)/len(valid_loader)),
               ))
    predictions = np.concatenate(preds).reshape(-1)
    return losses.avg, predictions, np.array(targets), np.array(filenames)

# %% [markdown]
# ## Train loop

# %%
# ====================================================
# Train loop
# ====================================================
def train_loop(train_tfrecords: np.ndarray, val_tfrecords: np.ndarray, fold: int):
    
    LOGGER.info(f"========== fold: {fold} training ==========")
    
    # ====================================================
    # scheduler 
    # ====================================================
    def get_scheduler(optimizer):
        if CFG.scheduler=='ReduceLROnPlateau':
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 
                                                             mode='min', 
                                                             factor=CFG.factor, 
                                                             patience=CFG.patience, 
                                                             verbose=True, 
                                                             eps=CFG.eps)
        elif CFG.scheduler=='CosineAnnealingLR':
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, 
                                                             T_max=CFG.T_max, 
                                                             eta_min=CFG.min_lr, 
                                                             last_epoch=-1)
        elif CFG.scheduler=='CosineAnnealingWarmRestarts':
            scheduler = optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, 
                                                                       T_0=CFG.T_0, 
                                                                       T_mult=1, 
                                                                       eta_min=CFG.min_lr, 
                                                                       last_epoch=-1)
        return scheduler

    # ====================================================
    # model & optimizer
    # ====================================================
    model = CNN1d()
    model.to(device)
    model = nn.DataParallel(model)


    optimizer = optim.Adam(model.parameters(), lr=CFG.lr, weight_decay=CFG.weight_decay)
    scheduler = get_scheduler(optimizer)

    # ====================================================
    # loop
    # ====================================================
    criterion = nn.BCEWithLogitsLoss()

    best_score = 0.
    best_loss = np.inf
    
    for epoch in range(CFG.epochs):
        print("\n\n")
        start_time = time.time()
        
        # train
        avg_loss = train_fn(train_tfrecords, model, criterion, optimizer, epoch, scheduler, device)

        # eval
        avg_val_loss, preds, targets, files = valid_fn(val_tfrecords, model, criterion, device)
        valid_result_df = pd.DataFrame({"target": targets, "preds": preds, "id": files})
        
        if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
            scheduler.step(avg_val_loss)
        elif isinstance(scheduler, optim.lr_scheduler.CosineAnnealingLR):
            scheduler.step()
        elif isinstance(scheduler, optim.lr_scheduler.CosineAnnealingWarmRestarts):
            scheduler.step()

        # scoring
        score = get_score(targets, preds)

        elapsed = time.time() - start_time

        LOGGER.info(f'Epoch {epoch+1} - avg_train_loss: {avg_loss:.4f}  avg_val_loss: {avg_val_loss:.4f}  time: {elapsed:.0f}s')
        LOGGER.info(f'Epoch {epoch+1} - Score: {score:.4f}')

        if score > best_score:
            best_score = score
            LOGGER.info(f'Epoch {epoch+1} - Save Best Score: {best_score:.4f} Model')
            torch.save({'model': model.state_dict(), 
                        'preds': preds},
                        SAVEDIR / f'{CFG.model_name}_fold{fold}_best_score.pth')
        
        if avg_val_loss < best_loss:
            best_loss = avg_val_loss
            LOGGER.info(f'Epoch {epoch+1} - Save Best Loss: {best_loss:.4f} Model')
            torch.save({'model': model.state_dict(), 
                        'preds': preds},
                        SAVEDIR / f'{CFG.model_name}_fold{fold}_best_loss.pth')
    
    valid_result_df["preds"] = torch.load(SAVEDIR / f"{CFG.model_name}_fold{fold}_best_loss.pth",
                                          map_location="cpu")["preds"]

    return valid_result_df

# %%
torch.cuda.empty_cache()

# %%
def get_result(result_df):
    preds = result_df['preds'].values
    labels = result_df[CFG.target_col].values
    score = get_score(labels, preds)
    LOGGER.info(f'Score: {score:<.4f}')

if CFG.train:
    # train 
    oof_df = pd.DataFrame()
    kf = KFold(n_splits=CFG.n_fold, shuffle=True, random_state=CFG.seed)

    folds = list(kf.split(all_files))
    for fold in range(CFG.n_fold):
        if fold in CFG.trn_fold:
            trn_idx, val_idx = folds[fold]
            train_files = all_files[trn_idx]
            valid_files = all_files[val_idx]
            _oof_df = train_loop(train_files, valid_files, fold)
            oof_df = pd.concat([oof_df, _oof_df])
            LOGGER.info(f"========== fold: {fold} result ==========")
            get_result(_oof_df)
    # CV result
    LOGGER.info(f"========== CV ==========")
    get_result(oof_df)
    # save result
    oof_df.to_csv(SAVEDIR / 'oof_df.csv', index=False)
# Out:
# ========== fold: 0 training ==========
# C:\Users\heinz\anaconda3\lib\site-packages\torch\cuda\nccl.py:16: UserWarning: PyTorch is not compiled with NCCL support
#   warnings.warn('PyTorch is not compiled with NCCL support')
# Epoch: [1/5][0/438] Loss: 0.7359(0.7359) Grad: 3.6658  LR: 0.000100  Elapsed: 0m 8s (remain 58m 49s) Max mem: 2935 MB
# Epoch: [1/5][1/438] Loss: 0.7347(0.7353) Grad: 3.4208  LR: 0.000100  Elapsed: 0m 10s (remain 36m 32s) Max mem: 2962 MB
# Epoch: [1/5][2/438] Loss: 0.7415(0.7374) Grad: 3.2382  LR: 0.000100  Elapsed: 0m 11s (remain 28m 59s) Max mem: 2962 MB
# Epoch: [1/5][3/438] Loss: 0.7387(0.7377) Grad: 3.1395  LR: 0.000100  Elapsed: 0m 14s (remain 25m 41s) Max mem: 2962 MB
# Epoch: [1/5][4/438] Loss: 0.7437(0.7389) Grad: 2.9424  LR: 0.000100  Elapsed: 0m 16s (remain 23m 39s) Max mem: 2962 MB
# Epoch: [1/5][5/438] Loss: 0.7345(0.7382) Grad: 2.8518  LR: 0.000100  Elapsed: 0m 18s (remain 22m 12s) Max mem: 2962 MB
# Epoch: [1/5][6/438] Loss: 0.7068(0.7337) Grad: 2.6047  LR: 0.000100  Elapsed: 0m 20s (remain 21m 10s) Max mem: 2962 MB
# Epoch: [1/5][7/438] Loss: 0.7304(0.7333) Grad: 2.5366  LR: 0.000100  Elapsed: 0m 22s (remain 20m 20s) Max mem: 2962 MB
# Epoch: [1/5][8/438] Loss: 0.7396(0.7340) Grad: 2.5716  LR: 0.000100  Elapsed: 0m 24s (remain 19m 42s) Max mem: 2962 MB
# Epoch: [1/5][9/438] Loss: 0.7259(0.7332) Grad: 2.5105  LR: 0.000100  Elapsed: 0m 26s (remain 19m 12s) Max mem: 2962 MB
# Epoch: [1/5][10/438] Loss: 0.7304(0.7329) Grad: 2.4911  LR: 0.000100  Elapsed: 0m 29s (remain 18m 49s) Max mem: 2962 MB
# Epoch: [1/5][11/438] Loss: 0.7272(0.7324) Grad: 2.3810  LR: 0.000100  Elapsed: 0m 31s (remain 18m 37s) Max mem: 2962 MB
# Epoch: [1/5][12/438] Loss: 0.7232(0.7317) Grad: 2.3231  LR: 0.000100  Elapsed: 0m 33s (remain 18m 18s) Max mem: 2962 MB
# Epoch: [1/5][13/438] Loss: 0.7239(0.7312) Grad: 2.2708  LR: 0.000100  Elapsed: 0m 35s (remain 17m 57s) Max mem: 2962 MB
# Epoch: [1/5][14/438] Loss: 0.7128(0.7299) Grad: 2.2229  LR: 0.000100  Elapsed: 0m 37s (remain 17m 41s) Max mem: 2962 MB
# Epoch: [1/5][15/438] Loss: 0.7072(0.7285) Grad: 2.2998  LR: 0.000100  Elapsed: 0m 39s (remain 17m 26s) Max mem: 2962 MB
# Epoch: [1/5][16/438] Loss: 0.7227(0.7282) Grad: 2.2114  LR: 0.000100  Elapsed: 0m 41s (remain 17m 13s) Max mem: 2962 MB
# Epoch: [1/5][17/438] Loss: 0.7162(0.7275) Grad: 2.1731  LR: 0.000100  Elapsed: 0m 43s (remain 17m 2s) Max mem: 2962 MB
# Epoch: [1/5][18/438] Loss: 0.7126(0.7267) Grad: 2.1501  LR: 0.000100  Elapsed: 0m 45s (remain 16m 51s) Max mem: 2962 MB
# Epoch: [1/5][19/438] Loss: 0.7204(0.7264) Grad: 2.1276  LR: 0.000100  Elapsed: 0m 47s (remain 16m 41s) Max mem: 2962 MB
# Epoch: [1/5][20/438] Loss: 0.7120(0.7257) Grad: 2.0309  LR: 0.000100  Elapsed: 0m 49s (remain 16m 31s) Max mem: 2962 MB
# Epoch: [1/5][21/438] Loss: 0.7274(0.7258) Grad: 2.0412  LR: 0.000100  Elapsed: 0m 51s (remain 16m 22s) Max mem: 2962 MB
# Epoch: [1/5][22/438] Loss: 0.7078(0.7250) Grad: 2.0131  LR: 0.000100  Elapsed: 0m 54s (remain 16m 14s) Max mem: 2962 MB
# Epoch: [1/5][23/438] Loss: 0.7357(0.7255) Grad: 1.9889  LR: 0.000100  Elapsed: 0m 56s (remain 16m 7s) Max mem: 2962 MB
# Epoch: [1/5][24/438] Loss: 0.7110(0.7249) Grad: 1.9601  LR: 0.000100  Elapsed: 0m 58s (remain 15m 59s) Max mem: 2962 MB
# Epoch: [1/5][25/438] Loss: 0.7185(0.7246) Grad: 1.9907  LR: 0.000100  Elapsed: 1m 0s (remain 15m 52s) Max mem: 2962 MB
# Epoch: [1/5][26/438] Loss: 0.7031(0.7238) Grad: 1.9714  LR: 0.000100  Elapsed: 1m 2s (remain 15m 45s) Max mem: 2962 MB
# Epoch: [1/5][27/438] Loss: 0.6899(0.7226) Grad: 1.9358  LR: 0.000100  Elapsed: 1m 4s (remain 15m 40s) Max mem: 2962 MB
# Epoch: [1/5][28/438] Loss: 0.7160(0.7224) Grad: 1.9474  LR: 0.000100  Elapsed: 1m 6s (remain 15m 35s) Max mem: 2962 MB
# Epoch: [1/5][29/438] Loss: 0.6978(0.7216) Grad: 1.8547  LR: 0.000100  Elapsed: 1m 8s (remain 15m 29s) Max mem: 2962 MB
# Epoch: [1/5][30/438] Loss: 0.6885(0.7205) Grad: 1.8999  LR: 0.000100  Elapsed: 1m 10s (remain 15m 23s) Max mem: 2962 MB
# Epoch: [1/5][31/438] Loss: 0.6827(0.7193) Grad: 1.8619  LR: 0.000100  Elapsed: 1m 12s (remain 15m 17s) Max mem: 2962 MB
# Epoch: [1/5][32/438] Loss: 0.7084(0.7190) Grad: 1.8949  LR: 0.000100  Elapsed: 1m 14s (remain 15m 12s) Max mem: 2962 MB
# Epoch: [1/5][33/438] Loss: 0.6774(0.7178) Grad: 1.7906  LR: 0.000100  Elapsed: 1m 16s (remain 15m 7s) Max mem: 2962 MB
# Epoch: [1/5][34/438] Loss: 0.6857(0.7169) Grad: 1.7735  LR: 0.000100  Elapsed: 1m 18s (remain 15m 4s) Max mem: 2962 MB
# Epoch: [1/5][35/438] Loss: 0.7046(0.7165) Grad: 1.8084  LR: 0.000100  Elapsed: 1m 20s (remain 15m 0s) Max mem: 2962 MB
# Epoch: [1/5][36/438] Loss: 0.6884(0.7158) Grad: 1.7973  LR: 0.000100  Elapsed: 1m 22s (remain 14m 55s) Max mem: 2962 MB
# Epoch: [1/5][37/438] Loss: 0.6865(0.7150) Grad: 1.7885  LR: 0.000100  Elapsed: 1m 24s (remain 14m 52s) Max mem: 2962 MB
# Epoch: [1/5][38/438] Loss: 0.6828(0.7142) Grad: 1.7511  LR: 0.000100  Elapsed: 1m 26s (remain 14m 48s) Max mem: 2962 MB
# Epoch: [1/5][39/438] Loss: 0.6774(0.7132) Grad: 1.8182  LR: 0.000100  Elapsed: 1m 29s (remain 14m 46s) Max mem: 2962 MB
# Epoch: [1/5][40/438] Loss: 0.6623(0.7120) Grad: 1.7073  LR: 0.000100  Elapsed: 1m 31s (remain 14m 44s) Max mem: 2962 MB
# Epoch: [1/5][41/438] Loss: 0.6733(0.7111) Grad: 1.7803  LR: 0.000100  Elapsed: 1m 33s (remain 14m 45s) Max mem: 2962 MB
# Epoch: [1/5][42/438] Loss: 0.6642(0.7100) Grad: 1.6208  LR: 0.000100  Elapsed: 1m 36s (remain 14m 44s) Max mem: 2962 MB
# Epoch: [1/5][43/438] Loss: 0.6850(0.7094) Grad: 1.7273  LR: 0.000100  Elapsed: 1m 38s (remain 14m 42s) Max mem: 2962 MB
# Epoch: [1/5][44/438] Loss: 0.6635(0.7084) Grad: 1.6857  LR: 0.000100  Elapsed: 1m 41s (remain 14m 42s) Max mem: 2962 MB
# Epoch: [1/5][45/438] Loss: 0.6775(0.7077) Grad: 2.0964  LR: 0.000100  Elapsed: 1m 43s (remain 14m 40s) Max mem: 2962 MB
# Epoch: [1/5][46/438] Loss: 0.6693(0.7069) Grad: 1.5404  LR: 0.000100  Elapsed: 1m 45s (remain 14m 39s) Max mem: 2962 MB
# Epoch: [1/5][47/438] Loss: 0.6636(0.7060) Grad: 1.5757  LR: 0.000100  Elapsed: 1m 48s (remain 14m 40s) Max mem: 2962 MB
# Epoch: [1/5][48/438] Loss: 0.6585(0.7050) Grad: 1.6171  LR: 0.000100  Elapsed: 1m 50s (remain 14m 38s) Max mem: 2962 MB
# Epoch: [1/5][49/438] Loss: 0.6749(0.7044) Grad: 1.6372  LR: 0.000100  Elapsed: 1m 53s (remain 14m 36s) Max mem: 2962 MB
# Epoch: [1/5][50/438] Loss: 0.6588(0.7035) Grad: 1.5549  LR: 0.000100  Elapsed: 1m 55s (remain 14m 34s) Max mem: 2962 MB
# Epoch: [1/5][51/438] Loss: 0.6673(0.7028) Grad: 1.8827  LR: 0.000100  Elapsed: 1m 57s (remain 14m 30s) Max mem: 2962 MB
# Epoch: [1/5][52/438] Loss: 0.6708(0.7022) Grad: 1.7094  LR: 0.000100  Elapsed: 1m 59s (remain 14m 27s) Max mem: 2962 MB
# Epoch: [1/5][53/438] Loss: 0.6451(0.7012) Grad: 1.5212  LR: 0.000100  Elapsed: 2m 1s (remain 14m 23s) Max mem: 2962 MB
# Epoch: [1/5][54/438] Loss: 0.6703(0.7006) Grad: 2.4174  LR: 0.000100  Elapsed: 2m 3s (remain 14m 20s) Max mem: 2962 MB
# Epoch: [1/5][55/438] Loss: 0.6432(0.6996) Grad: 1.8189  LR: 0.000100  Elapsed: 2m 5s (remain 14m 16s) Max mem: 2962 MB
# Epoch: [1/5][56/438] Loss: 0.6540(0.6988) Grad: 1.6522  LR: 0.000100  Elapsed: 2m 7s (remain 14m 12s) Max mem: 2962 MB
# Epoch: [1/5][57/438] Loss: 0.6509(0.6980) Grad: 1.4995  LR: 0.000100  Elapsed: 2m 9s (remain 14m 7s) Max mem: 2962 MB
# Epoch: [1/5][58/438] Loss: 0.6465(0.6971) Grad: 1.4865  LR: 0.000100  Elapsed: 2m 11s (remain 14m 3s) Max mem: 2962 MB
# Epoch: [1/5][59/438] Loss: 0.6565(0.6964) Grad: 1.7567  LR: 0.000100  Elapsed: 2m 13s (remain 13m 59s) Max mem: 2962 MB
# Epoch: [1/5][60/438] Loss: 0.6382(0.6955) Grad: 2.0743  LR: 0.000100  Elapsed: 2m 15s (remain 13m 55s) Max mem: 2962 MB
# Epoch: [1/5][61/438] Loss: 0.6472(0.6947) Grad: 1.6681  LR: 0.000100  Elapsed: 2m 17s (remain 13m 51s) Max mem: 2962 MB
# Epoch: [1/5][62/438] Loss: 0.6278(0.6936) Grad: 1.3523  LR: 0.000100  Elapsed: 2m 18s (remain 13m 47s) Max mem: 2962 MB
# Epoch: [1/5][63/438] Loss: 0.6393(0.6928) Grad: 1.6294  LR: 0.000100  Elapsed: 2m 20s (remain 13m 43s) Max mem: 2962 MB
# Epoch: [1/5][64/438] Loss: 0.6449(0.6920) Grad: 1.6091  LR: 0.000100  Elapsed: 2m 22s (remain 13m 39s) Max mem: 2962 MB
# Epoch: [1/5][65/438] Loss: 0.6218(0.6910) Grad: 1.4949  LR: 0.000100  Elapsed: 2m 24s (remain 13m 35s) Max mem: 2962 MB
# Epoch: [1/5][66/438] Loss: 0.6163(0.6899) Grad: 1.2986  LR: 0.000100  Elapsed: 2m 26s (remain 13m 33s) Max mem: 2962 MB
# Epoch: [1/5][67/438] Loss: 0.6354(0.6891) Grad: 1.4859  LR: 0.000100  Elapsed: 2m 29s (remain 13m 32s) Max mem: 2962 MB
# Epoch: [1/5][68/438] Loss: 0.6265(0.6882) Grad: 1.3706  LR: 0.000100  Elapsed: 2m 31s (remain 13m 29s) Max mem: 2962 MB
# Epoch: [1/5][69/438] Loss: 0.6249(0.6873) Grad: 1.3371  LR: 0.000100  Elapsed: 2m 33s (remain 13m 25s) Max mem: 2962 MB
# Epoch: [1/5][70/438] Loss: 0.6194(0.6863) Grad: 1.2632  LR: 0.000100  Elapsed: 2m 35s (remain 13m 22s) Max mem: 2962 MB
# Epoch: [1/5][71/438] Loss: 0.6277(0.6855) Grad: 1.2805  LR: 0.000100  Elapsed: 2m 37s (remain 13m 18s) Max mem: 2962 MB
# Epoch: [1/5][72/438] Loss: 0.6302(0.6847) Grad: 1.4031  LR: 0.000100  Elapsed: 2m 38s (remain 13m 14s) Max mem: 2962 MB
# Epoch: [1/5][73/438] Loss: 0.6067(0.6837) Grad: 1.6333  LR: 0.000100  Elapsed: 2m 40s (remain 13m 10s) Max mem: 2962 MB
# Epoch: [1/5][74/438] Loss: 0.6063(0.6826) Grad: 1.4012  LR: 0.000100  Elapsed: 2m 42s (remain 13m 7s) Max mem: 2962 MB
# Epoch: [1/5][75/438] Loss: 0.6307(0.6820) Grad: 1.3638  LR: 0.000100  Elapsed: 2m 44s (remain 13m 5s) Max mem: 2962 MB
# Epoch: [1/5][76/438] Loss: 0.6210(0.6812) Grad: 1.8665  LR: 0.000100  Elapsed: 2m 47s (remain 13m 3s) Max mem: 2962 MB
# Epoch: [1/5][77/438] Loss: 0.5946(0.6801) Grad: 1.2587  LR: 0.000100  Elapsed: 2m 49s (remain 13m 0s) Max mem: 2962 MB
# Epoch: [1/5][78/438] Loss: 0.6079(0.6791) Grad: 1.4787  LR: 0.000100  Elapsed: 2m 51s (remain 12m 58s) Max mem: 2962 MB
# Epoch: [1/5][79/438] Loss: 0.6017(0.6782) Grad: 1.7383  LR: 0.000100  Elapsed: 2m 53s (remain 12m 55s) Max mem: 2962 MB
# Epoch: [1/5][80/438] Loss: 0.5918(0.6771) Grad: 1.4999  LR: 0.000100  Elapsed: 2m 55s (remain 12m 51s) Max mem: 2962 MB
# Epoch: [1/5][81/438] Loss: 0.6036(0.6762) Grad: 1.1812  LR: 0.000100  Elapsed: 2m 57s (remain 12m 48s) Max mem: 2962 MB
# Epoch: [1/5][82/438] Loss: 0.6132(0.6755) Grad: 1.4758  LR: 0.000100  Elapsed: 2m 59s (remain 12m 45s) Max mem: 2962 MB
# Epoch: [1/5][83/438] Loss: 0.5912(0.6744) Grad: 1.5007  LR: 0.000100  Elapsed: 3m 0s (remain 12m 42s) Max mem: 2962 MB
# Epoch: [1/5][84/438] Loss: 0.5952(0.6735) Grad: 1.2467  LR: 0.000100  Elapsed: 3m 2s (remain 12m 39s) Max mem: 2962 MB
# Epoch: [1/5][85/438] Loss: 0.5866(0.6725) Grad: 1.7799  LR: 0.000100  Elapsed: 3m 4s (remain 12m 36s) Max mem: 2962 MB
# Epoch: [1/5][86/438] Loss: 0.5804(0.6714) Grad: 1.4156  LR: 0.000100  Elapsed: 3m 6s (remain 12m 33s) Max mem: 2962 MB
# Epoch: [1/5][87/438] Loss: 0.5993(0.6706) Grad: 1.5813  LR: 0.000100  Elapsed: 3m 8s (remain 12m 30s) Max mem: 2962 MB
# Epoch: [1/5][88/438] Loss: 0.5670(0.6695) Grad: 1.8469  LR: 0.000100  Elapsed: 3m 10s (remain 12m 27s) Max mem: 2962 MB
# Epoch: [1/5][89/438] Loss: 0.5998(0.6687) Grad: 1.3385  LR: 0.000100  Elapsed: 3m 12s (remain 12m 24s) Max mem: 2962 MB
# Epoch: [1/5][90/438] Loss: 0.5820(0.6677) Grad: 1.6850  LR: 0.000100  Elapsed: 3m 14s (remain 12m 21s) Max mem: 2962 MB
# Epoch: [1/5][91/438] Loss: 0.5830(0.6668) Grad: 2.2350  LR: 0.000100  Elapsed: 3m 16s (remain 12m 19s) Max mem: 2962 MB
# Epoch: [1/5][92/438] Loss: 0.5850(0.6659) Grad: 1.4684  LR: 0.000100  Elapsed: 3m 18s (remain 12m 16s) Max mem: 2962 MB
# Epoch: [1/5][93/438] Loss: 0.5738(0.6650) Grad: 1.6489  LR: 0.000100  Elapsed: 3m 20s (remain 12m 13s) Max mem: 2962 MB
# Epoch: [1/5][94/438] Loss: 0.5893(0.6642) Grad: 1.3720  LR: 0.000100  Elapsed: 3m 22s (remain 12m 12s) Max mem: 2962 MB
# Epoch: [1/5][95/438] Loss: 0.5870(0.6634) Grad: 1.1839  LR: 0.000100  Elapsed: 3m 24s (remain 12m 9s) Max mem: 2962 MB
# Epoch: [1/5][96/438] Loss: 0.5611(0.6623) Grad: 1.7749  LR: 0.000100  Elapsed: 3m 26s (remain 12m 7s) Max mem: 2962 MB
# Epoch: [1/5][97/438] Loss: 0.5806(0.6615) Grad: 1.3896  LR: 0.000100  Elapsed: 3m 28s (remain 12m 4s) Max mem: 2962 MB
# Epoch: [1/5][98/438] Loss: 0.5738(0.6606) Grad: 2.9040  LR: 0.000100  Elapsed: 3m 30s (remain 12m 2s) Max mem: 2962 MB
# Epoch: [1/5][99/438] Loss: 0.5870(0.6598) Grad: 1.4124  LR: 0.000100  Elapsed: 3m 33s (remain 12m 0s) Max mem: 2962 MB
# Epoch: [1/5][100/438] Loss: 0.5661(0.6589) Grad: 2.0429  LR: 0.000100  Elapsed: 3m 35s (remain 11m 58s) Max mem: 2962 MB
# Epoch: [1/5][101/438] Loss: 0.5920(0.6583) Grad: 2.5284  LR: 0.000100  Elapsed: 3m 37s (remain 11m 56s) Max mem: 2962 MB
# Epoch: [1/5][102/438] Loss: 0.5534(0.6572) Grad: 2.8198  LR: 0.000100  Elapsed: 3m 39s (remain 11m 53s) Max mem: 2962 MB
# Epoch: [1/5][103/438] Loss: 0.6013(0.6567) Grad: 2.2961  LR: 0.000100  Elapsed: 3m 41s (remain 11m 50s) Max mem: 2962 MB
# Epoch: [1/5][104/438] Loss: 0.5604(0.6558) Grad: 1.7774  LR: 0.000100  Elapsed: 3m 43s (remain 11m 48s) Max mem: 2962 MB
# Epoch: [1/5][105/438] Loss: 0.5568(0.6549) Grad: 1.4263  LR: 0.000100  Elapsed: 3m 45s (remain 11m 45s) Max mem: 2962 MB
# Epoch: [1/5][106/438] Loss: 0.5641(0.6540) Grad: 2.3214  LR: 0.000100  Elapsed: 3m 47s (remain 11m 42s) Max mem: 2962 MB
# Epoch: [1/5][107/438] Loss: 0.5580(0.6531) Grad: 2.3317  LR: 0.000100  Elapsed: 3m 48s (remain 11m 39s) Max mem: 2962 MB
# Epoch: [1/5][108/438] Loss: 0.5646(0.6523) Grad: 1.6842  LR: 0.000100  Elapsed: 3m 50s (remain 11m 36s) Max mem: 2962 MB
# Epoch: [1/5][109/438] Loss: 0.5502(0.6514) Grad: 3.0648  LR: 0.000100  Elapsed: 3m 53s (remain 11m 35s) Max mem: 2962 MB
# Epoch: [1/5][110/438] Loss: 0.5784(0.6507) Grad: 2.8292  LR: 0.000100  Elapsed: 3m 55s (remain 11m 33s) Max mem: 2962 MB
# Epoch: [1/5][111/438] Loss: 0.5558(0.6499) Grad: 3.3550  LR: 0.000100  Elapsed: 3m 57s (remain 11m 32s) Max mem: 2962 MB
# Epoch: [1/5][112/438] Loss: 0.5585(0.6491) Grad: 1.5869  LR: 0.000100  Elapsed: 4m 0s (remain 11m 30s) Max mem: 2962 MB
# Epoch: [1/5][113/438] Loss: 0.5500(0.6482) Grad: 2.5003  LR: 0.000100  Elapsed: 4m 2s (remain 11m 28s) Max mem: 2962 MB
# Epoch: [1/5][114/438] Loss: 0.5435(0.6473) Grad: 1.5642  LR: 0.000100  Elapsed: 4m 4s (remain 11m 26s) Max mem: 2962 MB
# Epoch: [1/5][115/438] Loss: 0.5508(0.6465) Grad: 3.3159  LR: 0.000100  Elapsed: 4m 6s (remain 11m 23s) Max mem: 2962 MB
# Epoch: [1/5][116/438] Loss: 0.5635(0.6457) Grad: 1.8706  LR: 0.000100  Elapsed: 4m 8s (remain 11m 21s) Max mem: 2962 MB
# Epoch: [1/5][117/438] Loss: 0.5719(0.6451) Grad: 4.4680  LR: 0.000100  Elapsed: 4m 10s (remain 11m 20s) Max mem: 2962 MB
# Epoch: [1/5][118/438] Loss: 0.5749(0.6445) Grad: 2.4039  LR: 0.000100  Elapsed: 4m 14s (remain 11m 21s) Max mem: 2962 MB
# Epoch: [1/5][119/438] Loss: 0.5542(0.6438) Grad: 3.1002  LR: 0.000100  Elapsed: 4m 16s (remain 11m 20s) Max mem: 2962 MB
# Epoch: [1/5][120/438] Loss: 0.5679(0.6431) Grad: 4.7089  LR: 0.000100  Elapsed: 4m 19s (remain 11m 19s) Max mem: 2962 MB
# Epoch: [1/5][121/438] Loss: 0.5633(0.6425) Grad: 2.3675  LR: 0.000100  Elapsed: 4m 22s (remain 11m 18s) Max mem: 2962 MB
# Epoch: [1/5][122/438] Loss: 0.5557(0.6418) Grad: 2.4026  LR: 0.000100  Elapsed: 4m 24s (remain 11m 18s) Max mem: 2962 MB
# Epoch: [1/5][123/438] Loss: 0.5541(0.6411) Grad: 4.0941  LR: 0.000100  Elapsed: 4m 28s (remain 11m 19s) Max mem: 2962 MB
# Epoch: [1/5][124/438] Loss: 0.5647(0.6405) Grad: 3.6162  LR: 0.000100  Elapsed: 4m 31s (remain 11m 18s) Max mem: 2962 MB
# Epoch: [1/5][125/438] Loss: 0.5617(0.6398) Grad: 1.9295  LR: 0.000100  Elapsed: 4m 33s (remain 11m 16s) Max mem: 2962 MB
# Epoch: [1/5][126/438] Loss: 0.5743(0.6393) Grad: 4.9722  LR: 0.000100  Elapsed: 4m 35s (remain 11m 14s) Max mem: 2962 MB
# Epoch: [1/5][127/438] Loss: 0.5578(0.6387) Grad: 3.9737  LR: 0.000100  Elapsed: 4m 37s (remain 11m 11s) Max mem: 2962 MB
# Epoch: [1/5][128/438] Loss: 0.5452(0.6380) Grad: 1.5157  LR: 0.000100  Elapsed: 4m 39s (remain 11m 9s) Max mem: 2962 MB
# Epoch: [1/5][129/438] Loss: 0.5722(0.6375) Grad: 3.3181  LR: 0.000100  Elapsed: 4m 41s (remain 11m 6s) Max mem: 2962 MB
# Epoch: [1/5][130/438] Loss: 0.5742(0.6370) Grad: 3.3838  LR: 0.000100  Elapsed: 4m 43s (remain 11m 4s) Max mem: 2962 MB
# Epoch: [1/5][131/438] Loss: 0.5392(0.6362) Grad: 1.5776  LR: 0.000100  Elapsed: 4m 45s (remain 11m 1s) Max mem: 2962 MB
# Epoch: [1/5][132/438] Loss: 0.5353(0.6355) Grad: 3.0511  LR: 0.000100  Elapsed: 4m 47s (remain 10m 59s) Max mem: 2962 MB
# Epoch: [1/5][133/438] Loss: 0.5529(0.6349) Grad: 3.3065  LR: 0.000100  Elapsed: 4m 49s (remain 10m 57s) Max mem: 2962 MB
# Epoch: [1/5][134/438] Loss: 0.5616(0.6343) Grad: 1.5881  LR: 0.000100  Elapsed: 4m 51s (remain 10m 54s) Max mem: 2962 MB
# Epoch: [1/5][135/438] Loss: 0.5340(0.6336) Grad: 1.1598  LR: 0.000100  Elapsed: 4m 53s (remain 10m 52s) Max mem: 2962 MB
# Epoch: [1/5][136/438] Loss: 0.5355(0.6329) Grad: 1.2945  LR: 0.000100  Elapsed: 4m 55s (remain 10m 49s) Max mem: 2962 MB
# Epoch: [1/5][137/438] Loss: 0.5428(0.6322) Grad: 1.5282  LR: 0.000100  Elapsed: 4m 57s (remain 10m 47s) Max mem: 2962 MB
# Epoch: [1/5][138/438] Loss: 0.5498(0.6316) Grad: 1.2637  LR: 0.000100  Elapsed: 5m 0s (remain 10m 45s) Max mem: 2962 MB
# Epoch: [1/5][139/438] Loss: 0.5369(0.6309) Grad: 1.3648  LR: 0.000100  Elapsed: 5m 2s (remain 10m 42s) Max mem: 2962 MB
# Epoch: [1/5][140/438] Loss: 0.5271(0.6302) Grad: 0.8797  LR: 0.000100  Elapsed: 5m 4s (remain 10m 40s) Max mem: 2962 MB
# Epoch: [1/5][141/438] Loss: 0.5371(0.6296) Grad: 1.3014  LR: 0.000100  Elapsed: 5m 6s (remain 10m 38s) Max mem: 2962 MB
# Epoch: [1/5][142/438] Loss: 0.5463(0.6290) Grad: 1.3696  LR: 0.000100  Elapsed: 5m 8s (remain 10m 36s) Max mem: 2962 MB
# Epoch: [1/5][143/438] Loss: 0.5271(0.6283) Grad: 1.0602  LR: 0.000100  Elapsed: 5m 10s (remain 10m 33s) Max mem: 2962 MB
# Epoch: [1/5][144/438] Loss: 0.5294(0.6276) Grad: 1.7081  LR: 0.000100  Elapsed: 5m 12s (remain 10m 31s) Max mem: 2962 MB
# Epoch: [1/5][145/438] Loss: 0.5443(0.6270) Grad: 2.2698  LR: 0.000100  Elapsed: 5m 14s (remain 10m 28s) Max mem: 2962 MB
# Epoch: [1/5][146/438] Loss: 0.5365(0.6264) Grad: 1.2006  LR: 0.000100  Elapsed: 5m 16s (remain 10m 26s) Max mem: 2962 MB
# Epoch: [1/5][147/438] Loss: 0.5499(0.6259) Grad: 2.1650  LR: 0.000100  Elapsed: 5m 19s (remain 10m 25s) Max mem: 2962 MB
# Epoch: [1/5][148/438] Loss: 0.5343(0.6253) Grad: 1.4383  LR: 0.000100  Elapsed: 5m 20s (remain 10m 22s) Max mem: 2962 MB
# Epoch: [1/5][149/438] Loss: 0.5304(0.6246) Grad: 1.0906  LR: 0.000100  Elapsed: 5m 22s (remain 10m 19s) Max mem: 2962 MB
# Epoch: [1/5][150/438] Loss: 0.5377(0.6241) Grad: 1.4095  LR: 0.000100  Elapsed: 5m 24s (remain 10m 16s) Max mem: 2962 MB
# Epoch: [1/5][151/438] Loss: 0.5658(0.6237) Grad: 1.8108  LR: 0.000100  Elapsed: 5m 26s (remain 10m 14s) Max mem: 2962 MB
# Epoch: [1/5][152/438] Loss: 0.5262(0.6230) Grad: 2.1230  LR: 0.000100  Elapsed: 5m 28s (remain 10m 11s) Max mem: 2962 MB
# Epoch: [1/5][153/438] Loss: 0.5494(0.6226) Grad: 1.6795  LR: 0.000100  Elapsed: 5m 29s (remain 10m 8s) Max mem: 2962 MB
# Epoch: [1/5][154/438] Loss: 0.5356(0.6220) Grad: 1.8511  LR: 0.000100  Elapsed: 5m 31s (remain 10m 5s) Max mem: 2962 MB
# Epoch: [1/5][155/438] Loss: 0.5340(0.6214) Grad: 1.9533  LR: 0.000100  Elapsed: 5m 33s (remain 10m 3s) Max mem: 2962 MB
# Epoch: [1/5][156/438] Loss: 0.5367(0.6209) Grad: 2.4936  LR: 0.000100  Elapsed: 5m 35s (remain 10m 0s) Max mem: 2962 MB
# Epoch: [1/5][157/438] Loss: 0.5482(0.6204) Grad: 1.7521  LR: 0.000100  Elapsed: 5m 37s (remain 9m 57s) Max mem: 2962 MB
# Epoch: [1/5][158/438] Loss: 0.5442(0.6200) Grad: 3.7380  LR: 0.000100  Elapsed: 5m 38s (remain 9m 54s) Max mem: 2962 MB
# Epoch: [1/5][159/438] Loss: 0.5546(0.6195) Grad: 3.8597  LR: 0.000100  Elapsed: 5m 40s (remain 9m 52s) Max mem: 2962 MB
# Epoch: [1/5][160/438] Loss: 0.5574(0.6192) Grad: 1.7595  LR: 0.000100  Elapsed: 5m 42s (remain 9m 50s) Max mem: 2962 MB
# Epoch: [1/5][161/438] Loss: 0.5453(0.6187) Grad: 2.8818  LR: 0.000100  Elapsed: 5m 45s (remain 9m 47s) Max mem: 2962 MB
# Epoch: [1/5][162/438] Loss: 0.5548(0.6183) Grad: 2.7936  LR: 0.000100  Elapsed: 5m 46s (remain 9m 45s) Max mem: 2962 MB
# Epoch: [1/5][163/438] Loss: 0.5374(0.6178) Grad: 2.2048  LR: 0.000100  Elapsed: 5m 48s (remain 9m 42s) Max mem: 2962 MB
# Epoch: [1/5][164/438] Loss: 0.5351(0.6173) Grad: 1.1891  LR: 0.000100  Elapsed: 5m 50s (remain 9m 40s) Max mem: 2962 MB
# Epoch: [1/5][165/438] Loss: 0.5108(0.6167) Grad: 2.8791  LR: 0.000100  Elapsed: 5m 52s (remain 9m 38s) Max mem: 2962 MB
# Epoch: [1/5][166/438] Loss: 0.5290(0.6161) Grad: 2.5618  LR: 0.000100  Elapsed: 5m 54s (remain 9m 35s) Max mem: 2962 MB
# Epoch: [1/5][167/438] Loss: 0.5469(0.6157) Grad: 2.5930  LR: 0.000100  Elapsed: 5m 56s (remain 9m 33s) Max mem: 2962 MB
# Epoch: [1/5][168/438] Loss: 0.5121(0.6151) Grad: 1.0222  LR: 0.000100  Elapsed: 5m 58s (remain 9m 31s) Max mem: 2962 MB
# Epoch: [1/5][169/438] Loss: 0.5456(0.6147) Grad: 2.2141  LR: 0.000100  Elapsed: 6m 0s (remain 9m 28s) Max mem: 2962 MB
# Epoch: [1/5][170/438] Loss: 0.5395(0.6143) Grad: 3.1041  LR: 0.000100  Elapsed: 6m 2s (remain 9m 26s) Max mem: 2962 MB
# Epoch: [1/5][171/438] Loss: 0.5441(0.6139) Grad: 1.4641  LR: 0.000100  Elapsed: 6m 4s (remain 9m 23s) Max mem: 2962 MB
# Epoch: [1/5][172/438] Loss: 0.5327(0.6134) Grad: 1.7048  LR: 0.000100  Elapsed: 6m 6s (remain 9m 21s) Max mem: 2962 MB
# Epoch: [1/5][173/438] Loss: 0.5507(0.6130) Grad: 1.7263  LR: 0.000100  Elapsed: 6m 8s (remain 9m 18s) Max mem: 2962 MB
# Epoch: [1/5][174/438] Loss: 0.5177(0.6125) Grad: 2.1734  LR: 0.000100  Elapsed: 6m 9s (remain 9m 15s) Max mem: 2962 MB
# Epoch: [1/5][175/438] Loss: 0.5496(0.6121) Grad: 3.6674  LR: 0.000100  Elapsed: 6m 11s (remain 9m 13s) Max mem: 2962 MB
# Epoch: [1/5][176/438] Loss: 0.5422(0.6117) Grad: 1.9691  LR: 0.000100  Elapsed: 6m 13s (remain 9m 10s) Max mem: 2962 MB
# Epoch: [1/5][177/438] Loss: 0.5311(0.6113) Grad: 1.6868  LR: 0.000100  Elapsed: 6m 15s (remain 9m 8s) Max mem: 2962 MB
# Epoch: [1/5][178/438] Loss: 0.5386(0.6109) Grad: 3.4250  LR: 0.000100  Elapsed: 6m 16s (remain 9m 5s) Max mem: 2962 MB
# Epoch: [1/5][179/438] Loss: 0.5552(0.6106) Grad: 1.7631  LR: 0.000100  Elapsed: 6m 18s (remain 9m 2s) Max mem: 2962 MB
# Epoch: [1/5][180/438] Loss: 0.5483(0.6102) Grad: 1.1553  LR: 0.000100  Elapsed: 6m 20s (remain 9m 0s) Max mem: 2962 MB
# Epoch: [1/5][181/438] Loss: 0.5131(0.6097) Grad: 1.3258  LR: 0.000100  Elapsed: 6m 22s (remain 8m 58s) Max mem: 2962 MB
# Epoch: [1/5][182/438] Loss: 0.5450(0.6093) Grad: 1.2504  LR: 0.000100  Elapsed: 6m 24s (remain 8m 55s) Max mem: 2962 MB
# Epoch: [1/5][183/438] Loss: 0.5453(0.6090) Grad: 1.5287  LR: 0.000100  Elapsed: 6m 26s (remain 8m 53s) Max mem: 2962 MB
# Epoch: [1/5][184/438] Loss: 0.5106(0.6085) Grad: 1.2250  LR: 0.000100  Elapsed: 6m 28s (remain 8m 51s) Max mem: 2962 MB
# Epoch: [1/5][185/438] Loss: 0.5258(0.6080) Grad: 1.4241  LR: 0.000100  Elapsed: 6m 30s (remain 8m 48s) Max mem: 2962 MB
# Epoch: [1/5][186/438] Loss: 0.5401(0.6076) Grad: 1.6651  LR: 0.000100  Elapsed: 6m 32s (remain 8m 46s) Max mem: 2962 MB
# Epoch: [1/5][187/438] Loss: 0.4927(0.6070) Grad: 1.0381  LR: 0.000100  Elapsed: 6m 33s (remain 8m 43s) Max mem: 2962 MB
# Epoch: [1/5][188/438] Loss: 0.5152(0.6066) Grad: 2.1198  LR: 0.000100  Elapsed: 6m 35s (remain 8m 41s) Max mem: 2962 MB
# Epoch: [1/5][189/438] Loss: 0.5431(0.6062) Grad: 2.6523  LR: 0.000100  Elapsed: 6m 37s (remain 8m 39s) Max mem: 2962 MB
# Epoch: [1/5][190/438] Loss: 0.5143(0.6057) Grad: 1.6598  LR: 0.000100  Elapsed: 6m 39s (remain 8m 36s) Max mem: 2962 MB
# Epoch: [1/5][191/438] Loss: 0.5380(0.6054) Grad: 1.8834  LR: 0.000100  Elapsed: 6m 41s (remain 8m 34s) Max mem: 2962 MB
# Epoch: [1/5][192/438] Loss: 0.5307(0.6050) Grad: 1.3808  LR: 0.000100  Elapsed: 6m 43s (remain 8m 32s) Max mem: 2962 MB
# Epoch: [1/5][193/438] Loss: 0.5377(0.6047) Grad: 1.3808  LR: 0.000100  Elapsed: 6m 45s (remain 8m 29s) Max mem: 2962 MB
# Epoch: [1/5][194/438] Loss: 0.5214(0.6042) Grad: 1.7409  LR: 0.000100  Elapsed: 6m 47s (remain 8m 27s) Max mem: 2962 MB
# Epoch: [1/5][195/438] Loss: 0.5393(0.6039) Grad: 1.0227  LR: 0.000100  Elapsed: 6m 49s (remain 8m 25s) Max mem: 2962 MB
# Epoch: [1/5][196/438] Loss: 0.4800(0.6033) Grad: 1.3084  LR: 0.000100  Elapsed: 6m 51s (remain 8m 23s) Max mem: 2962 MB
# Epoch: [1/5][197/438] Loss: 0.5148(0.6028) Grad: 1.0081  LR: 0.000100  Elapsed: 6m 53s (remain 8m 20s) Max mem: 2962 MB
# Epoch: [1/5][198/438] Loss: 0.5261(0.6024) Grad: 2.3838  LR: 0.000100  Elapsed: 6m 55s (remain 8m 18s) Max mem: 2962 MB
# Epoch: [1/5][199/438] Loss: 0.5748(0.6023) Grad: 1.3101  LR: 0.000100  Elapsed: 6m 57s (remain 8m 16s) Max mem: 2962 MB
# Epoch: [1/5][200/438] Loss: 0.5422(0.6020) Grad: 2.3314  LR: 0.000100  Elapsed: 6m 59s (remain 8m 14s) Max mem: 2962 MB
# Epoch: [1/5][201/438] Loss: 0.5282(0.6016) Grad: 1.6551  LR: 0.000100  Elapsed: 7m 1s (remain 8m 11s) Max mem: 2962 MB
# Epoch: [1/5][202/438] Loss: 0.5249(0.6013) Grad: 1.1777  LR: 0.000100  Elapsed: 7m 2s (remain 8m 9s) Max mem: 2962 MB
# Epoch: [1/5][203/438] Loss: 0.5431(0.6010) Grad: 1.0361  LR: 0.000100  Elapsed: 7m 4s (remain 8m 7s) Max mem: 2962 MB
# Epoch: [1/5][204/438] Loss: 0.5134(0.6005) Grad: 0.9675  LR: 0.000100  Elapsed: 7m 6s (remain 8m 5s) Max mem: 2962 MB
# Epoch: [1/5][205/438] Loss: 0.5321(0.6002) Grad: 1.0952  LR: 0.000100  Elapsed: 7m 8s (remain 8m 2s) Max mem: 2962 MB
# Epoch: [1/5][206/438] Loss: 0.5553(0.6000) Grad: 1.2701  LR: 0.000100  Elapsed: 7m 10s (remain 8m 0s) Max mem: 2962 MB
# Epoch: [1/5][207/438] Loss: 0.5372(0.5997) Grad: 1.0094  LR: 0.000100  Elapsed: 7m 12s (remain 7m 58s) Max mem: 2962 MB
# Epoch: [1/5][208/438] Loss: 0.5250(0.5993) Grad: 1.1848  LR: 0.000100  Elapsed: 7m 14s (remain 7m 55s) Max mem: 2962 MB
# Epoch: [1/5][209/438] Loss: 0.5502(0.5991) Grad: 1.2271  LR: 0.000100  Elapsed: 7m 16s (remain 7m 53s) Max mem: 2962 MB
# Epoch: [1/5][210/438] Loss: 0.5238(0.5987) Grad: 1.2841  LR: 0.000100  Elapsed: 7m 18s (remain 7m 51s) Max mem: 2962 MB
# Epoch: [1/5][211/438] Loss: 0.5322(0.5984) Grad: 1.0154  LR: 0.000100  Elapsed: 7m 20s (remain 7m 49s) Max mem: 2962 MB
# Epoch: [1/5][212/438] Loss: 0.5315(0.5981) Grad: 0.8147  LR: 0.000100  Elapsed: 7m 22s (remain 7m 47s) Max mem: 2962 MB
# Epoch: [1/5][213/438] Loss: 0.5423(0.5979) Grad: 1.1771  LR: 0.000100  Elapsed: 7m 24s (remain 7m 44s) Max mem: 2962 MB
# Epoch: [1/5][214/438] Loss: 0.5263(0.5975) Grad: 1.9631  LR: 0.000100  Elapsed: 7m 25s (remain 7m 42s) Max mem: 2962 MB
# Epoch: [1/5][215/438] Loss: 0.5348(0.5972) Grad: 1.1601  LR: 0.000100  Elapsed: 7m 27s (remain 7m 40s) Max mem: 2962 MB
# Epoch: [1/5][216/438] Loss: 0.5321(0.5969) Grad: 1.4522  LR: 0.000100  Elapsed: 7m 29s (remain 7m 38s) Max mem: 2962 MB
# Epoch: [1/5][217/438] Loss: 0.5225(0.5966) Grad: 2.1850  LR: 0.000100  Elapsed: 7m 31s (remain 7m 35s) Max mem: 2962 MB
# Epoch: [1/5][218/438] Loss: 0.5107(0.5962) Grad: 1.1727  LR: 0.000100  Elapsed: 7m 33s (remain 7m 33s) Max mem: 2962 MB
# Epoch: [1/5][219/438] Loss: 0.5171(0.5958) Grad: 1.1758  LR: 0.000100  Elapsed: 7m 35s (remain 7m 31s) Max mem: 2962 MB
# Epoch: [1/5][220/438] Loss: 0.5491(0.5956) Grad: 1.2096  LR: 0.000100  Elapsed: 7m 37s (remain 7m 29s) Max mem: 2962 MB
# Epoch: [1/5][221/438] Loss: 0.5088(0.5952) Grad: 1.5112  LR: 0.000100  Elapsed: 7m 39s (remain 7m 27s) Max mem: 2962 MB
# Epoch: [1/5][222/438] Loss: 0.5141(0.5949) Grad: 1.2326  LR: 0.000100  Elapsed: 7m 41s (remain 7m 24s) Max mem: 2962 MB
# Epoch: [1/5][223/438] Loss: 0.5379(0.5946) Grad: 1.2086  LR: 0.000100  Elapsed: 7m 43s (remain 7m 22s) Max mem: 2962 MB
# Epoch: [1/5][224/438] Loss: 0.5200(0.5943) Grad: 0.9499  LR: 0.000100  Elapsed: 7m 45s (remain 7m 20s) Max mem: 2962 MB
# Epoch: [1/5][225/438] Loss: 0.5296(0.5940) Grad: 1.1066  LR: 0.000100  Elapsed: 7m 46s (remain 7m 18s) Max mem: 2962 MB
# Epoch: [1/5][226/438] Loss: 0.5196(0.5937) Grad: 1.7711  LR: 0.000100  Elapsed: 7m 48s (remain 7m 15s) Max mem: 2962 MB
# Epoch: [1/5][227/438] Loss: 0.5081(0.5933) Grad: 1.1793  LR: 0.000100  Elapsed: 7m 50s (remain 7m 13s) Max mem: 2962 MB
# Epoch: [1/5][228/438] Loss: 0.5225(0.5930) Grad: 1.9795  LR: 0.000100  Elapsed: 7m 52s (remain 7m 11s) Max mem: 2962 MB
# Epoch: [1/5][229/438] Loss: 0.5414(0.5928) Grad: 1.4327  LR: 0.000100  Elapsed: 7m 54s (remain 7m 9s) Max mem: 2962 MB
# Epoch: [1/5][230/438] Loss: 0.5207(0.5924) Grad: 1.5449  LR: 0.000100  Elapsed: 7m 56s (remain 7m 6s) Max mem: 2962 MB
# Epoch: [1/5][231/438] Loss: 0.5366(0.5922) Grad: 1.4575  LR: 0.000100  Elapsed: 7m 58s (remain 7m 4s) Max mem: 2962 MB
# Epoch: [1/5][232/438] Loss: 0.5231(0.5919) Grad: 2.2104  LR: 0.000100  Elapsed: 8m 0s (remain 7m 2s) Max mem: 2962 MB
# Epoch: [1/5][233/438] Loss: 0.5070(0.5915) Grad: 2.9060  LR: 0.000100  Elapsed: 8m 1s (remain 7m 0s) Max mem: 2962 MB
# Epoch: [1/5][234/438] Loss: 0.5337(0.5913) Grad: 1.1177  LR: 0.000100  Elapsed: 8m 3s (remain 6m 57s) Max mem: 2962 MB
# Epoch: [1/5][235/438] Loss: 0.5196(0.5910) Grad: 2.4603  LR: 0.000100  Elapsed: 8m 5s (remain 6m 55s) Max mem: 2962 MB
# Epoch: [1/5][236/438] Loss: 0.5300(0.5907) Grad: 1.2680  LR: 0.000100  Elapsed: 8m 7s (remain 6m 53s) Max mem: 2962 MB
# Epoch: [1/5][237/438] Loss: 0.5198(0.5904) Grad: 1.1462  LR: 0.000100  Elapsed: 8m 8s (remain 6m 50s) Max mem: 2962 MB
# Epoch: [1/5][238/438] Loss: 0.5196(0.5901) Grad: 1.0200  LR: 0.000100  Elapsed: 8m 10s (remain 6m 48s) Max mem: 2962 MB
# Epoch: [1/5][239/438] Loss: 0.5179(0.5898) Grad: 1.0757  LR: 0.000100  Elapsed: 8m 12s (remain 6m 46s) Max mem: 2962 MB
# Epoch: [1/5][240/438] Loss: 0.5130(0.5895) Grad: 1.2150  LR: 0.000100  Elapsed: 8m 14s (remain 6m 44s) Max mem: 2962 MB
# Epoch: [1/5][241/438] Loss: 0.5051(0.5892) Grad: 2.6162  LR: 0.000100  Elapsed: 8m 16s (remain 6m 41s) Max mem: 2962 MB
# Epoch: [1/5][242/438] Loss: 0.5284(0.5889) Grad: 1.3388  LR: 0.000100  Elapsed: 8m 17s (remain 6m 39s) Max mem: 2962 MB
# Epoch: [1/5][243/438] Loss: 0.5272(0.5887) Grad: 1.1995  LR: 0.000100  Elapsed: 8m 19s (remain 6m 37s) Max mem: 2962 MB
# Epoch: [1/5][244/438] Loss: 0.5283(0.5884) Grad: 1.2330  LR: 0.000100  Elapsed: 8m 21s (remain 6m 35s) Max mem: 2962 MB
# Epoch: [1/5][245/438] Loss: 0.5279(0.5882) Grad: 1.2677  LR: 0.000100  Elapsed: 8m 23s (remain 6m 32s) Max mem: 2962 MB
# Epoch: [1/5][246/438] Loss: 0.5314(0.5880) Grad: 1.0178  LR: 0.000100  Elapsed: 8m 25s (remain 6m 30s) Max mem: 2962 MB
# Epoch: [1/5][247/438] Loss: 0.5356(0.5877) Grad: 1.2282  LR: 0.000100  Elapsed: 8m 26s (remain 6m 28s) Max mem: 2962 MB
# Epoch: [1/5][248/438] Loss: 0.5126(0.5874) Grad: 1.0464  LR: 0.000100  Elapsed: 8m 28s (remain 6m 26s) Max mem: 2962 MB
# Epoch: [1/5][249/438] Loss: 0.5018(0.5871) Grad: 1.5285  LR: 0.000100  Elapsed: 8m 30s (remain 6m 23s) Max mem: 2962 MB
# Epoch: [1/5][250/438] Loss: 0.5172(0.5868) Grad: 1.4047  LR: 0.000100  Elapsed: 8m 32s (remain 6m 21s) Max mem: 2962 MB
# Epoch: [1/5][251/438] Loss: 0.5134(0.5865) Grad: 1.9290  LR: 0.000100  Elapsed: 8m 34s (remain 6m 19s) Max mem: 2962 MB
# Epoch: [1/5][252/438] Loss: 0.5186(0.5863) Grad: 1.6879  LR: 0.000100  Elapsed: 8m 36s (remain 6m 17s) Max mem: 2962 MB
# Epoch: [1/5][253/438] Loss: 0.4954(0.5859) Grad: 0.9107  LR: 0.000100  Elapsed: 8m 38s (remain 6m 15s) Max mem: 2962 MB
# Epoch: [1/5][254/438] Loss: 0.5319(0.5857) Grad: 1.5559  LR: 0.000100  Elapsed: 8m 39s (remain 6m 13s) Max mem: 2962 MB
# Epoch: [1/5][255/438] Loss: 0.5229(0.5854) Grad: 1.3545  LR: 0.000100  Elapsed: 8m 41s (remain 6m 10s) Max mem: 2962 MB
# Epoch: [1/5][256/438] Loss: 0.5260(0.5852) Grad: 1.1325  LR: 0.000100  Elapsed: 8m 43s (remain 6m 8s) Max mem: 2962 MB
# Epoch: [1/5][257/438] Loss: 0.5542(0.5851) Grad: 1.1791  LR: 0.000100  Elapsed: 8m 45s (remain 6m 6s) Max mem: 2962 MB
# Epoch: [1/5][258/438] Loss: 0.5403(0.5849) Grad: 0.9653  LR: 0.000100  Elapsed: 8m 47s (remain 6m 4s) Max mem: 2962 MB
# Epoch: [1/5][259/438] Loss: 0.5042(0.5846) Grad: 1.3097  LR: 0.000100  Elapsed: 8m 49s (remain 6m 2s) Max mem: 2962 MB
# Epoch: [1/5][260/438] Loss: 0.5298(0.5844) Grad: 1.6904  LR: 0.000100  Elapsed: 8m 50s (remain 5m 59s) Max mem: 2962 MB
# Epoch: [1/5][261/438] Loss: 0.5305(0.5842) Grad: 2.2769  LR: 0.000100  Elapsed: 8m 52s (remain 5m 57s) Max mem: 2962 MB
# Epoch: [1/5][262/438] Loss: 0.5435(0.5840) Grad: 1.2481  LR: 0.000100  Elapsed: 8m 54s (remain 5m 55s) Max mem: 2962 MB
# Epoch: [1/5][263/438] Loss: 0.5220(0.5838) Grad: 1.4317  LR: 0.000100  Elapsed: 8m 56s (remain 5m 53s) Max mem: 2962 MB
# Epoch: [1/5][264/438] Loss: 0.5005(0.5835) Grad: 1.1536  LR: 0.000100  Elapsed: 8m 58s (remain 5m 51s) Max mem: 2962 MB
# Epoch: [1/5][265/438] Loss: 0.5322(0.5833) Grad: 1.1399  LR: 0.000100  Elapsed: 8m 59s (remain 5m 49s) Max mem: 2962 MB
# Epoch: [1/5][266/438] Loss: 0.5081(0.5830) Grad: 1.3247  LR: 0.000100  Elapsed: 9m 1s (remain 5m 46s) Max mem: 2962 MB
# Epoch: [1/5][267/438] Loss: 0.5355(0.5828) Grad: 1.2098  LR: 0.000100  Elapsed: 9m 3s (remain 5m 44s) Max mem: 2962 MB
# Epoch: [1/5][268/438] Loss: 0.5060(0.5826) Grad: 0.8360  LR: 0.000100  Elapsed: 9m 5s (remain 5m 42s) Max mem: 2962 MB
# Epoch: [1/5][269/438] Loss: 0.5188(0.5823) Grad: 1.4890  LR: 0.000100  Elapsed: 9m 6s (remain 5m 40s) Max mem: 2962 MB
# Epoch: [1/5][270/438] Loss: 0.5092(0.5820) Grad: 1.3130  LR: 0.000100  Elapsed: 9m 8s (remain 5m 38s) Max mem: 2962 MB
# Epoch: [1/5][271/438] Loss: 0.5122(0.5818) Grad: 1.1427  LR: 0.000100  Elapsed: 9m 10s (remain 5m 35s) Max mem: 2962 MB
# Epoch: [1/5][272/438] Loss: 0.5154(0.5815) Grad: 0.9119  LR: 0.000100  Elapsed: 9m 12s (remain 5m 33s) Max mem: 2962 MB
# Epoch: [1/5][273/438] Loss: 0.5295(0.5814) Grad: 1.3558  LR: 0.000100  Elapsed: 9m 13s (remain 5m 31s) Max mem: 2962 MB
# Epoch: [1/5][274/438] Loss: 0.4969(0.5810) Grad: 1.1877  LR: 0.000100  Elapsed: 9m 15s (remain 5m 29s) Max mem: 2962 MB
# Epoch: [1/5][275/438] Loss: 0.5223(0.5808) Grad: 1.9029  LR: 0.000100  Elapsed: 9m 17s (remain 5m 27s) Max mem: 2962 MB
# Epoch: [1/5][276/438] Loss: 0.5400(0.5807) Grad: 1.2347  LR: 0.000100  Elapsed: 9m 19s (remain 5m 25s) Max mem: 2962 MB
# Epoch: [1/5][277/438] Loss: 0.5066(0.5804) Grad: 1.5475  LR: 0.000100  Elapsed: 9m 21s (remain 5m 22s) Max mem: 2962 MB
# Epoch: [1/5][278/438] Loss: 0.5415(0.5803) Grad: 1.4915  LR: 0.000100  Elapsed: 9m 22s (remain 5m 20s) Max mem: 2962 MB
# Epoch: [1/5][279/438] Loss: 0.5109(0.5800) Grad: 1.5587  LR: 0.000100  Elapsed: 9m 24s (remain 5m 18s) Max mem: 2962 MB
# Epoch: [1/5][280/438] Loss: 0.5027(0.5798) Grad: 0.8757  LR: 0.000100  Elapsed: 9m 26s (remain 5m 16s) Max mem: 2962 MB
# Epoch: [1/5][281/438] Loss: 0.5225(0.5796) Grad: 1.1634  LR: 0.000100  Elapsed: 9m 28s (remain 5m 14s) Max mem: 2962 MB
# Epoch: [1/5][282/438] Loss: 0.5209(0.5793) Grad: 0.8615  LR: 0.000100  Elapsed: 9m 29s (remain 5m 12s) Max mem: 2962 MB
# Epoch: [1/5][283/438] Loss: 0.4865(0.5790) Grad: 1.0707  LR: 0.000100  Elapsed: 9m 31s (remain 5m 10s) Max mem: 2962 MB
# Epoch: [1/5][284/438] Loss: 0.5016(0.5787) Grad: 1.1217  LR: 0.000100  Elapsed: 9m 33s (remain 5m 7s) Max mem: 2962 MB
# Epoch: [1/5][285/438] Loss: 0.5249(0.5786) Grad: 0.9559  LR: 0.000100  Elapsed: 9m 35s (remain 5m 5s) Max mem: 2962 MB
# Epoch: [1/5][286/438] Loss: 0.5213(0.5784) Grad: 0.9677  LR: 0.000100  Elapsed: 9m 36s (remain 5m 3s) Max mem: 2962 MB
# Epoch: [1/5][287/438] Loss: 0.5376(0.5782) Grad: 1.5484  LR: 0.000100  Elapsed: 9m 38s (remain 5m 1s) Max mem: 2962 MB
# Epoch: [1/5][288/438] Loss: 0.5425(0.5781) Grad: 1.2061  LR: 0.000100  Elapsed: 9m 40s (remain 4m 59s) Max mem: 2962 MB
# Epoch: [1/5][289/438] Loss: 0.5173(0.5779) Grad: 0.7827  LR: 0.000100  Elapsed: 9m 42s (remain 4m 57s) Max mem: 2962 MB
# Epoch: [1/5][290/438] Loss: 0.5137(0.5777) Grad: 1.0828  LR: 0.000100  Elapsed: 9m 44s (remain 4m 55s) Max mem: 2962 MB
# Epoch: [1/5][291/438] Loss: 0.5127(0.5774) Grad: 0.8305  LR: 0.000100  Elapsed: 9m 45s (remain 4m 52s) Max mem: 2962 MB
# Epoch: [1/5][292/438] Loss: 0.5360(0.5773) Grad: 0.9446  LR: 0.000100  Elapsed: 9m 47s (remain 4m 50s) Max mem: 2962 MB
# Epoch: [1/5][293/438] Loss: 0.4888(0.5770) Grad: 0.8834  LR: 0.000100  Elapsed: 9m 49s (remain 4m 48s) Max mem: 2962 MB
# Epoch: [1/5][294/438] Loss: 0.5240(0.5768) Grad: 2.1791  LR: 0.000100  Elapsed: 9m 51s (remain 4m 46s) Max mem: 2962 MB
# Epoch: [1/5][295/438] Loss: 0.5225(0.5766) Grad: 1.0017  LR: 0.000100  Elapsed: 9m 53s (remain 4m 44s) Max mem: 2962 MB
# Epoch: [1/5][296/438] Loss: 0.5068(0.5764) Grad: 1.4220  LR: 0.000100  Elapsed: 9m 54s (remain 4m 42s) Max mem: 2962 MB
# Epoch: [1/5][297/438] Loss: 0.5045(0.5762) Grad: 1.2070  LR: 0.000100  Elapsed: 9m 56s (remain 4m 40s) Max mem: 2962 MB
# Epoch: [1/5][298/438] Loss: 0.4993(0.5759) Grad: 1.1864  LR: 0.000100  Elapsed: 9m 58s (remain 4m 38s) Max mem: 2962 MB
# Epoch: [1/5][299/438] Loss: 0.5109(0.5757) Grad: 1.0533  LR: 0.000100  Elapsed: 10m 0s (remain 4m 36s) Max mem: 2962 MB
# Epoch: [1/5][300/438] Loss: 0.5088(0.5755) Grad: 1.9338  LR: 0.000100  Elapsed: 10m 1s (remain 4m 33s) Max mem: 2962 MB
# Epoch: [1/5][301/438] Loss: 0.5201(0.5753) Grad: 0.8632  LR: 0.000100  Elapsed: 10m 3s (remain 4m 31s) Max mem: 2962 MB
# Epoch: [1/5][302/438] Loss: 0.5107(0.5751) Grad: 1.1851  LR: 0.000100  Elapsed: 10m 5s (remain 4m 29s) Max mem: 2962 MB
# Epoch: [1/5][303/438] Loss: 0.5036(0.5748) Grad: 1.0825  LR: 0.000100  Elapsed: 10m 7s (remain 4m 27s) Max mem: 2962 MB
# Epoch: [1/5][304/438] Loss: 0.4937(0.5746) Grad: 0.9483  LR: 0.000100  Elapsed: 10m 9s (remain 4m 25s) Max mem: 2962 MB
# Epoch: [1/5][305/438] Loss: 0.5157(0.5744) Grad: 1.2250  LR: 0.000100  Elapsed: 10m 10s (remain 4m 23s) Max mem: 2962 MB
# Epoch: [1/5][306/438] Loss: 0.4977(0.5741) Grad: 0.9625  LR: 0.000100  Elapsed: 10m 12s (remain 4m 21s) Max mem: 2962 MB
# Epoch: [1/5][307/438] Loss: 0.5122(0.5739) Grad: 0.9957  LR: 0.000100  Elapsed: 10m 14s (remain 4m 19s) Max mem: 2962 MB
# Epoch: [1/5][308/438] Loss: 0.5119(0.5737) Grad: 1.4222  LR: 0.000100  Elapsed: 10m 16s (remain 4m 17s) Max mem: 2962 MB
# Epoch: [1/5][309/438] Loss: 0.4980(0.5735) Grad: 0.9035  LR: 0.000100  Elapsed: 10m 17s (remain 4m 15s) Max mem: 2962 MB
# Epoch: [1/5][310/438] Loss: 0.5039(0.5733) Grad: 1.0679  LR: 0.000100  Elapsed: 10m 19s (remain 4m 13s) Max mem: 2962 MB
# Epoch: [1/5][311/438] Loss: 0.4775(0.5729) Grad: 1.1383  LR: 0.000100  Elapsed: 10m 21s (remain 4m 10s) Max mem: 2962 MB
# Epoch: [1/5][312/438] Loss: 0.5113(0.5728) Grad: 1.3223  LR: 0.000100  Elapsed: 10m 23s (remain 4m 8s) Max mem: 2962 MB
# Epoch: [1/5][313/438] Loss: 0.5301(0.5726) Grad: 1.1988  LR: 0.000100  Elapsed: 10m 24s (remain 4m 6s) Max mem: 2962 MB
# Epoch: [1/5][314/438] Loss: 0.4897(0.5724) Grad: 1.0191  LR: 0.000100  Elapsed: 10m 26s (remain 4m 4s) Max mem: 2962 MB
# Epoch: [1/5][315/438] Loss: 0.5333(0.5722) Grad: 1.0111  LR: 0.000100  Elapsed: 10m 28s (remain 4m 2s) Max mem: 2962 MB
# Epoch: [1/5][316/438] Loss: 0.5087(0.5720) Grad: 0.9864  LR: 0.000100  Elapsed: 10m 30s (remain 4m 0s) Max mem: 2962 MB
# Epoch: [1/5][317/438] Loss: 0.5154(0.5719) Grad: 1.3297  LR: 0.000100  Elapsed: 10m 31s (remain 3m 58s) Max mem: 2962 MB
# Epoch: [1/5][318/438] Loss: 0.5176(0.5717) Grad: 0.9182  LR: 0.000100  Elapsed: 10m 33s (remain 3m 56s) Max mem: 2962 MB
# Epoch: [1/5][319/438] Loss: 0.5146(0.5715) Grad: 1.5897  LR: 0.000100  Elapsed: 10m 35s (remain 3m 54s) Max mem: 2962 MB
# Epoch: [1/5][320/438] Loss: 0.4902(0.5712) Grad: 1.3182  LR: 0.000100  Elapsed: 10m 37s (remain 3m 52s) Max mem: 2962 MB
# Epoch: [1/5][321/438] Loss: 0.5137(0.5711) Grad: 1.0317  LR: 0.000100  Elapsed: 10m 38s (remain 3m 50s) Max mem: 2962 MB
# Epoch: [1/5][322/438] Loss: 0.4971(0.5708) Grad: 1.1715  LR: 0.000100  Elapsed: 10m 40s (remain 3m 48s) Max mem: 2962 MB
# Epoch: [1/5][323/438] Loss: 0.4851(0.5706) Grad: 1.1141  LR: 0.000100  Elapsed: 10m 42s (remain 3m 45s) Max mem: 2962 MB
# Epoch: [1/5][324/438] Loss: 0.5433(0.5705) Grad: 1.1487  LR: 0.000100  Elapsed: 10m 43s (remain 3m 43s) Max mem: 2962 MB
# Epoch: [1/5][325/438] Loss: 0.4840(0.5702) Grad: 1.2250  LR: 0.000100  Elapsed: 10m 45s (remain 3m 41s) Max mem: 2962 MB
# Epoch: [1/5][326/438] Loss: 0.5051(0.5700) Grad: 1.2012  LR: 0.000100  Elapsed: 10m 47s (remain 3m 39s) Max mem: 2962 MB
# Epoch: [1/5][327/438] Loss: 0.5287(0.5699) Grad: 1.0217  LR: 0.000100  Elapsed: 10m 49s (remain 3m 37s) Max mem: 2962 MB
# Epoch: [1/5][328/438] Loss: 0.5298(0.5698) Grad: 1.7333  LR: 0.000100  Elapsed: 10m 51s (remain 3m 35s) Max mem: 2962 MB
# Epoch: [1/5][329/438] Loss: 0.5342(0.5697) Grad: 1.0018  LR: 0.000100  Elapsed: 10m 52s (remain 3m 33s) Max mem: 2962 MB
# Epoch: [1/5][330/438] Loss: 0.5115(0.5695) Grad: 1.5423  LR: 0.000100  Elapsed: 10m 54s (remain 3m 31s) Max mem: 2962 MB
# Epoch: [1/5][331/438] Loss: 0.5037(0.5693) Grad: 1.4134  LR: 0.000100  Elapsed: 10m 56s (remain 3m 29s) Max mem: 2962 MB
# Epoch: [1/5][332/438] Loss: 0.5185(0.5691) Grad: 1.0042  LR: 0.000100  Elapsed: 10m 58s (remain 3m 27s) Max mem: 2962 MB
# Epoch: [1/5][333/438] Loss: 0.4975(0.5689) Grad: 0.8697  LR: 0.000100  Elapsed: 11m 0s (remain 3m 25s) Max mem: 2962 MB
# Epoch: [1/5][334/438] Loss: 0.4978(0.5687) Grad: 1.0020  LR: 0.000100  Elapsed: 11m 2s (remain 3m 23s) Max mem: 2962 MB
# Epoch: [1/5][335/438] Loss: 0.4996(0.5685) Grad: 1.0584  LR: 0.000100  Elapsed: 11m 3s (remain 3m 21s) Max mem: 2962 MB
# Epoch: [1/5][336/438] Loss: 0.4912(0.5683) Grad: 0.8882  LR: 0.000100  Elapsed: 11m 5s (remain 3m 19s) Max mem: 2962 MB
# Epoch: [1/5][337/438] Loss: 0.4988(0.5681) Grad: 2.3220  LR: 0.000100  Elapsed: 11m 7s (remain 3m 17s) Max mem: 2962 MB
# Epoch: [1/5][338/438] Loss: 0.5074(0.5679) Grad: 0.9310  LR: 0.000100  Elapsed: 11m 9s (remain 3m 15s) Max mem: 2962 MB
# Epoch: [1/5][339/438] Loss: 0.5103(0.5677) Grad: 0.9701  LR: 0.000100  Elapsed: 11m 11s (remain 3m 13s) Max mem: 2962 MB
# Epoch: [1/5][340/438] Loss: 0.4978(0.5675) Grad: 1.2186  LR: 0.000100  Elapsed: 11m 13s (remain 3m 11s) Max mem: 2962 MB
# Epoch: [1/5][341/438] Loss: 0.4910(0.5673) Grad: 1.1210  LR: 0.000100  Elapsed: 11m 14s (remain 3m 9s) Max mem: 2962 MB
# Epoch: [1/5][342/438] Loss: 0.5124(0.5671) Grad: 1.1055  LR: 0.000100  Elapsed: 11m 16s (remain 3m 7s) Max mem: 2962 MB
# Epoch: [1/5][343/438] Loss: 0.5080(0.5670) Grad: 1.4404  LR: 0.000100  Elapsed: 11m 18s (remain 3m 5s) Max mem: 2962 MB
# Epoch: [1/5][344/438] Loss: 0.4963(0.5668) Grad: 1.2272  LR: 0.000100  Elapsed: 11m 20s (remain 3m 3s) Max mem: 2962 MB
# Epoch: [1/5][345/438] Loss: 0.5110(0.5666) Grad: 1.5554  LR: 0.000100  Elapsed: 11m 22s (remain 3m 1s) Max mem: 2962 MB
# Epoch: [1/5][346/438] Loss: 0.5059(0.5664) Grad: 1.8112  LR: 0.000100  Elapsed: 11m 24s (remain 2m 59s) Max mem: 2962 MB
# Epoch: [1/5][347/438] Loss: 0.4747(0.5662) Grad: 1.1198  LR: 0.000100  Elapsed: 11m 25s (remain 2m 57s) Max mem: 2962 MB
# Epoch: [1/5][348/438] Loss: 0.5176(0.5660) Grad: 0.8820  LR: 0.000100  Elapsed: 11m 27s (remain 2m 55s) Max mem: 2962 MB
# Epoch: [1/5][349/438] Loss: 0.5018(0.5658) Grad: 1.0429  LR: 0.000100  Elapsed: 11m 29s (remain 2m 53s) Max mem: 2962 MB
# Epoch: [1/5][350/438] Loss: 0.4983(0.5657) Grad: 1.9708  LR: 0.000100  Elapsed: 11m 31s (remain 2m 51s) Max mem: 2962 MB
# Epoch: [1/5][351/438] Loss: 0.4882(0.5654) Grad: 1.0909  LR: 0.000100  Elapsed: 11m 33s (remain 2m 49s) Max mem: 2962 MB
# Epoch: [1/5][352/438] Loss: 0.4869(0.5652) Grad: 1.7337  LR: 0.000100  Elapsed: 11m 35s (remain 2m 47s) Max mem: 2962 MB
# Epoch: [1/5][353/438] Loss: 0.4881(0.5650) Grad: 1.0904  LR: 0.000100  Elapsed: 11m 36s (remain 2m 45s) Max mem: 2962 MB
# Epoch: [1/5][354/438] Loss: 0.4897(0.5648) Grad: 1.1829  LR: 0.000100  Elapsed: 11m 38s (remain 2m 43s) Max mem: 2962 MB
# Epoch: [1/5][355/438] Loss: 0.5403(0.5647) Grad: 1.8818  LR: 0.000100  Elapsed: 11m 40s (remain 2m 41s) Max mem: 2962 MB
# Epoch: [1/5][356/438] Loss: 0.5172(0.5646) Grad: 1.1582  LR: 0.000100  Elapsed: 11m 42s (remain 2m 39s) Max mem: 2962 MB
# Epoch: [1/5][357/438] Loss: 0.4948(0.5644) Grad: 1.2892  LR: 0.000100  Elapsed: 11m 44s (remain 2m 37s) Max mem: 2962 MB
# Epoch: [1/5][358/438] Loss: 0.4879(0.5642) Grad: 1.1966  LR: 0.000100  Elapsed: 11m 46s (remain 2m 35s) Max mem: 2962 MB
# Epoch: [1/5][359/438] Loss: 0.5029(0.5640) Grad: 1.1285  LR: 0.000100  Elapsed: 11m 48s (remain 2m 33s) Max mem: 2962 MB
# Epoch: [1/5][360/438] Loss: 0.5034(0.5638) Grad: 1.1290  LR: 0.000100  Elapsed: 11m 49s (remain 2m 31s) Max mem: 2962 MB
# Epoch: [1/5][361/438] Loss: 0.5028(0.5637) Grad: 1.2189  LR: 0.000100  Elapsed: 11m 51s (remain 2m 29s) Max mem: 2962 MB
# Epoch: [1/5][362/438] Loss: 0.5043(0.5635) Grad: 1.2547  LR: 0.000100  Elapsed: 11m 53s (remain 2m 27s) Max mem: 2962 MB
# Epoch: [1/5][363/438] Loss: 0.5016(0.5633) Grad: 1.5437  LR: 0.000100  Elapsed: 11m 55s (remain 2m 25s) Max mem: 2962 MB
# Epoch: [1/5][364/438] Loss: 0.5024(0.5632) Grad: 1.3642  LR: 0.000100  Elapsed: 11m 56s (remain 2m 23s) Max mem: 2962 MB
# Epoch: [1/5][365/438] Loss: 0.4868(0.5630) Grad: 2.0007  LR: 0.000100  Elapsed: 11m 58s (remain 2m 21s) Max mem: 2962 MB
# Epoch: [1/5][366/438] Loss: 0.5218(0.5628) Grad: 1.0369  LR: 0.000100  Elapsed: 12m 0s (remain 2m 19s) Max mem: 2962 MB
# Epoch: [1/5][367/438] Loss: 0.4776(0.5626) Grad: 1.2593  LR: 0.000100  Elapsed: 12m 2s (remain 2m 17s) Max mem: 2962 MB
# Epoch: [1/5][368/438] Loss: 0.5094(0.5625) Grad: 1.1058  LR: 0.000100  Elapsed: 12m 3s (remain 2m 15s) Max mem: 2962 MB
# Epoch: [1/5][369/438] Loss: 0.5055(0.5623) Grad: 1.1532  LR: 0.000100  Elapsed: 12m 5s (remain 2m 13s) Max mem: 2962 MB
# Epoch: [1/5][370/438] Loss: 0.4911(0.5621) Grad: 1.0992  LR: 0.000100  Elapsed: 12m 7s (remain 2m 11s) Max mem: 2962 MB
# Epoch: [1/5][371/438] Loss: 0.5009(0.5620) Grad: 0.8999  LR: 0.000100  Elapsed: 12m 9s (remain 2m 9s) Max mem: 2962 MB
# Epoch: [1/5][372/438] Loss: 0.4820(0.5617) Grad: 0.9076  LR: 0.000100  Elapsed: 12m 10s (remain 2m 7s) Max mem: 2962 MB
# Epoch: [1/5][373/438] Loss: 0.4890(0.5615) Grad: 1.0510  LR: 0.000100  Elapsed: 12m 12s (remain 2m 5s) Max mem: 2962 MB
# Epoch: [1/5][374/438] Loss: 0.4973(0.5614) Grad: 1.4316  LR: 0.000100  Elapsed: 12m 14s (remain 2m 3s) Max mem: 2962 MB
# Epoch: [1/5][375/438] Loss: 0.5165(0.5613) Grad: 1.2907  LR: 0.000100  Elapsed: 12m 16s (remain 2m 1s) Max mem: 2962 MB
# Epoch: [1/5][376/438] Loss: 0.5233(0.5612) Grad: 1.1680  LR: 0.000100  Elapsed: 12m 17s (remain 1m 59s) Max mem: 2962 MB
# Epoch: [1/5][377/438] Loss: 0.5084(0.5610) Grad: 1.4008  LR: 0.000100  Elapsed: 12m 19s (remain 1m 57s) Max mem: 2962 MB
# Epoch: [1/5][378/438] Loss: 0.5238(0.5609) Grad: 1.7182  LR: 0.000100  Elapsed: 12m 21s (remain 1m 55s) Max mem: 2962 MB
# Epoch: [1/5][379/438] Loss: 0.5280(0.5608) Grad: 1.1239  LR: 0.000100  Elapsed: 12m 23s (remain 1m 53s) Max mem: 2962 MB
# Epoch: [1/5][380/438] Loss: 0.5004(0.5607) Grad: 1.0266  LR: 0.000100  Elapsed: 12m 24s (remain 1m 51s) Max mem: 2962 MB
# Epoch: [1/5][381/438] Loss: 0.4757(0.5604) Grad: 1.0835  LR: 0.000100  Elapsed: 12m 26s (remain 1m 49s) Max mem: 2962 MB
# Epoch: [1/5][382/438] Loss: 0.5027(0.5603) Grad: 1.7982  LR: 0.000100  Elapsed: 12m 28s (remain 1m 47s) Max mem: 2962 MB
# Epoch: [1/5][383/438] Loss: 0.5041(0.5602) Grad: 1.4315  LR: 0.000100  Elapsed: 12m 29s (remain 1m 45s) Max mem: 2962 MB
# Epoch: [1/5][384/438] Loss: 0.5149(0.5600) Grad: 1.4679  LR: 0.000100  Elapsed: 12m 31s (remain 1m 43s) Max mem: 2962 MB
# Epoch: [1/5][385/438] Loss: 0.4879(0.5598) Grad: 1.0962  LR: 0.000100  Elapsed: 12m 33s (remain 1m 41s) Max mem: 2962 MB
# Epoch: [1/5][386/438] Loss: 0.5123(0.5597) Grad: 1.6339  LR: 0.000100  Elapsed: 12m 35s (remain 1m 39s) Max mem: 2962 MB
# Epoch: [1/5][387/438] Loss: 0.4984(0.5596) Grad: 1.3454  LR: 0.000100  Elapsed: 12m 36s (remain 1m 37s) Max mem: 2962 MB
# Epoch: [1/5][388/438] Loss: 0.4920(0.5594) Grad: 0.8797  LR: 0.000100  Elapsed: 12m 38s (remain 1m 35s) Max mem: 2962 MB
# Epoch: [1/5][389/438] Loss: 0.5245(0.5593) Grad: 1.3151  LR: 0.000100  Elapsed: 12m 40s (remain 1m 33s) Max mem: 2962 MB
# Epoch: [1/5][390/438] Loss: 0.5082(0.5592) Grad: 1.2866  LR: 0.000100  Elapsed: 12m 42s (remain 1m 31s) Max mem: 2962 MB
# Epoch: [1/5][391/438] Loss: 0.4862(0.5590) Grad: 1.1964  LR: 0.000100  Elapsed: 12m 44s (remain 1m 29s) Max mem: 2962 MB
# Epoch: [1/5][392/438] Loss: 0.4786(0.5588) Grad: 1.2334  LR: 0.000100  Elapsed: 12m 45s (remain 1m 27s) Max mem: 2962 MB
# Epoch: [1/5][393/438] Loss: 0.5238(0.5587) Grad: 1.2812  LR: 0.000100  Elapsed: 12m 47s (remain 1m 25s) Max mem: 2962 MB
# Epoch: [1/5][394/438] Loss: 0.4938(0.5585) Grad: 1.3334  LR: 0.000100  Elapsed: 12m 49s (remain 1m 23s) Max mem: 2962 MB
# Epoch: [1/5][395/438] Loss: 0.4791(0.5583) Grad: 1.4278  LR: 0.000100  Elapsed: 12m 51s (remain 1m 21s) Max mem: 2962 MB
# Epoch: [1/5][396/438] Loss: 0.4976(0.5582) Grad: 1.1524  LR: 0.000100  Elapsed: 12m 53s (remain 1m 19s) Max mem: 2962 MB
# Epoch: [1/5][397/438] Loss: 0.4941(0.5580) Grad: 1.1112  LR: 0.000100  Elapsed: 12m 55s (remain 1m 17s) Max mem: 2962 MB
# ...
# Epoch: [2/5][375/438] Loss: 0.4655(0.4769) Grad: 1.3185  LR: 0.000075  Elapsed: 10m 22s (remain 1m 42s) Max mem: 2963 MB
# Epoch: [2/5][376/438] Loss: 0.4616(0.4768) Grad: 0.9516  LR: 0.000075  Elapsed: 10m 23s (remain 1m 40s) Max mem: 2963 MB
# Epoch: [2/5][377/438] Loss: 0.5051(0.4769) Grad: 1.1185  LR: 0.000075  Elapsed: 10m 25s (remain 1m 39s) Max mem: 2963 MB
# Epoch: [2/5][378/438] Loss: 0.4729(0.4769) Grad: 0.7837  LR: 0.000075  Elapsed: 10m 27s (remain 1m 37s) Max mem: 2963 MB
# Epoch: [2/5][379/438] Loss: 0.4792(0.4769) Grad: 1.2491  LR: 0.000075  Elapsed: 10m 29s (remain 1m 36s) Max mem: 2963 MB
# Epoch: [2/5][380/438] Loss: 0.4940(0.4770) Grad: 1.0827  LR: 0.000075  Elapsed: 10m 30s (remain 1m 34s) Max mem: 2963 MB
# Epoch: [2/5][381/438] Loss: 0.4984(0.4770) Grad: 1.0508  LR: 0.000075  Elapsed: 10m 32s (remain 1m 32s) Max mem: 2963 MB
# Epoch: [2/5][382/438] Loss: 0.4445(0.4769) Grad: 0.7978  LR: 0.000075  Elapsed: 10m 34s (remain 1m 31s) Max mem: 2963 MB
# Epoch: [2/5][383/438] Loss: 0.4714(0.4769) Grad: 0.9381  LR: 0.000075  Elapsed: 10m 36s (remain 1m 29s) Max mem: 2963 MB
# Epoch: [2/5][384/438] Loss: 0.4747(0.4769) Grad: 0.9689  LR: 0.000075  Elapsed: 10m 37s (remain 1m 27s) Max mem: 2963 MB
# Epoch: [2/5][385/438] Loss: 0.4725(0.4769) Grad: 1.0058  LR: 0.000075  Elapsed: 10m 39s (remain 1m 26s) Max mem: 2963 MB
# Epoch: [2/5][386/438] Loss: 0.4941(0.4769) Grad: 0.8934  LR: 0.000075  Elapsed: 10m 41s (remain 1m 24s) Max mem: 2963 MB
# Epoch: [2/5][387/438] Loss: 0.4623(0.4769) Grad: 1.0308  LR: 0.000075  Elapsed: 10m 42s (remain 1m 22s) Max mem: 2963 MB
# Epoch: [2/5][388/438] Loss: 0.4731(0.4769) Grad: 0.9660  LR: 0.000075  Elapsed: 10m 44s (remain 1m 21s) Max mem: 2963 MB
# Epoch: [2/5][389/438] Loss: 0.4437(0.4768) Grad: 0.9843  LR: 0.000075  Elapsed: 10m 46s (remain 1m 19s) Max mem: 2963 MB
# Epoch: [2/5][390/438] Loss: 0.4845(0.4768) Grad: 0.8615  LR: 0.000075  Elapsed: 10m 47s (remain 1m 17s) Max mem: 2963 MB
# Epoch: [2/5][391/438] Loss: 0.4642(0.4768) Grad: 0.9165  LR: 0.000075  Elapsed: 10m 49s (remain 1m 16s) Max mem: 2963 MB
# Epoch: [2/5][392/438] Loss: 0.4590(0.4768) Grad: 0.9173  LR: 0.000075  Elapsed: 10m 51s (remain 1m 14s) Max mem: 2963 MB
# Epoch: [2/5][393/438] Loss: 0.4404(0.4767) Grad: 0.8920  LR: 0.000075  Elapsed: 10m 53s (remain 1m 12s) Max mem: 2963 MB
# Epoch: [2/5][394/438] Loss: 0.4712(0.4766) Grad: 0.9189  LR: 0.000075  Elapsed: 10m 54s (remain 1m 11s) Max mem: 2963 MB
# Epoch: [2/5][395/438] Loss: 0.4695(0.4766) Grad: 1.0424  LR: 0.000075  Elapsed: 10m 56s (remain 1m 9s) Max mem: 2963 MB
# Epoch: [2/5][396/438] Loss: 0.4780(0.4766) Grad: 1.0307  LR: 0.000075  Elapsed: 10m 58s (remain 1m 7s) Max mem: 2963 MB
# Epoch: [2/5][397/438] Loss: 0.4506(0.4766) Grad: 0.9556  LR: 0.000075  Elapsed: 11m 0s (remain 1m 6s) Max mem: 2963 MB
# Epoch: [2/5][398/438] Loss: 0.4483(0.4765) Grad: 1.0788  LR: 0.000075  Elapsed: 11m 1s (remain 1m 4s) Max mem: 2963 MB
# Epoch: [2/5][399/438] Loss: 0.4558(0.4764) Grad: 1.1079  LR: 0.000075  Elapsed: 11m 3s (remain 1m 3s) Max mem: 2963 MB
# Epoch: [2/5][400/438] Loss: 0.4723(0.4764) Grad: 1.0001  LR: 0.000075  Elapsed: 11m 5s (remain 1m 1s) Max mem: 2963 MB
# Epoch: [2/5][401/438] Loss: 0.4799(0.4764) Grad: 1.0413  LR: 0.000075  Elapsed: 11m 7s (remain 0m 59s) Max mem: 2963 MB
# Epoch: [2/5][402/438] Loss: 0.4585(0.4764) Grad: 0.8712  LR: 0.000075  Elapsed: 11m 9s (remain 0m 58s) Max mem: 2963 MB
# Epoch: [2/5][403/438] Loss: 0.4629(0.4764) Grad: 0.8922  LR: 0.000075  Elapsed: 11m 10s (remain 0m 56s) Max mem: 2963 MB
# Epoch: [2/5][404/438] Loss: 0.4258(0.4762) Grad: 0.9140  LR: 0.000075  Elapsed: 11m 12s (remain 0m 54s) Max mem: 2963 MB
# Epoch: [2/5][405/438] Loss: 0.4704(0.4762) Grad: 0.9029  LR: 0.000075  Elapsed: 11m 14s (remain 0m 53s) Max mem: 2963 MB
# Epoch: [2/5][406/438] Loss: 0.4759(0.4762) Grad: 1.0663  LR: 0.000075  Elapsed: 11m 15s (remain 0m 51s) Max mem: 2963 MB
# Epoch: [2/5][407/438] Loss: 0.4711(0.4762) Grad: 0.8551  LR: 0.000075  Elapsed: 11m 17s (remain 0m 49s) Max mem: 2963 MB
# Epoch: [2/5][408/438] Loss: 0.4757(0.4762) Grad: 0.8790  LR: 0.000075  Elapsed: 11m 19s (remain 0m 48s) Max mem: 2963 MB
# Epoch: [2/5][409/438] Loss: 0.4407(0.4761) Grad: 0.8955  LR: 0.000075  Elapsed: 11m 21s (remain 0m 46s) Max mem: 2963 MB
# Epoch: [2/5][410/438] Loss: 0.4818(0.4761) Grad: 0.9963  LR: 0.000075  Elapsed: 11m 23s (remain 0m 44s) Max mem: 2963 MB
# Epoch: [2/5][411/438] Loss: 0.4414(0.4761) Grad: 1.0117  LR: 0.000075  Elapsed: 11m 24s (remain 0m 43s) Max mem: 2963 MB
# Epoch: [2/5][412/438] Loss: 0.4652(0.4760) Grad: 1.2058  LR: 0.000075  Elapsed: 11m 26s (remain 0m 41s) Max mem: 2963 MB
# Epoch: [2/5][413/438] Loss: 0.4824(0.4760) Grad: 0.8814  LR: 0.000075  Elapsed: 11m 28s (remain 0m 39s) Max mem: 2963 MB
# Epoch: [2/5][414/438] Loss: 0.4706(0.4760) Grad: 1.2442  LR: 0.000075  Elapsed: 11m 30s (remain 0m 38s) Max mem: 2963 MB
# Epoch: [2/5][415/438] Loss: 0.4412(0.4759) Grad: 0.9109  LR: 0.000075  Elapsed: 11m 32s (remain 0m 36s) Max mem: 2963 MB
# Epoch: [2/5][416/438] Loss: 0.4686(0.4759) Grad: 1.1455  LR: 0.000075  Elapsed: 11m 34s (remain 0m 34s) Max mem: 2963 MB
# Epoch: [2/5][417/438] Loss: 0.4708(0.4759) Grad: 1.5582  LR: 0.000075  Elapsed: 11m 36s (remain 0m 33s) Max mem: 2963 MB
# Epoch: [2/5][418/438] Loss: 0.4749(0.4759) Grad: 1.5002  LR: 0.000075  Elapsed: 11m 38s (remain 0m 31s) Max mem: 2963 MB
# Epoch: [2/5][419/438] Loss: 0.4509(0.4759) Grad: 0.9316  LR: 0.000075  Elapsed: 11m 41s (remain 0m 30s) Max mem: 2963 MB
# Epoch: [2/5][420/438] Loss: 0.4661(0.4758) Grad: 0.8930  LR: 0.000075  Elapsed: 11m 42s (remain 0m 28s) Max mem: 2963 MB
# Epoch: [2/5][421/438] Loss: 0.4550(0.4758) Grad: 0.9800  LR: 0.000075  Elapsed: 11m 44s (remain 0m 26s) Max mem: 2963 MB
# Epoch: [2/5][422/438] Loss: 0.4552(0.4757) Grad: 0.7306  LR: 0.000075  Elapsed: 11m 47s (remain 0m 25s) Max mem: 2963 MB
# Epoch: [2/5][423/438] Loss: 0.4708(0.4757) Grad: 1.1154  LR: 0.000075  Elapsed: 11m 49s (remain 0m 23s) Max mem: 2963 MB
# Epoch: [2/5][424/438] Loss: 0.4555(0.4757) Grad: 0.7816  LR: 0.000075  Elapsed: 11m 51s (remain 0m 21s) Max mem: 2963 MB
# Epoch: [2/5][425/438] Loss: 0.4871(0.4757) Grad: 0.9616  LR: 0.000075  Elapsed: 11m 54s (remain 0m 20s) Max mem: 2963 MB
# Epoch: [2/5][426/438] Loss: 0.4355(0.4756) Grad: 0.8297  LR: 0.000075  Elapsed: 11m 56s (remain 0m 18s) Max mem: 2963 MB
# Epoch: [2/5][427/438] Loss: 0.4668(0.4756) Grad: 1.0991  LR: 0.000075  Elapsed: 11m 58s (remain 0m 16s) Max mem: 2963 MB
# Epoch: [2/5][428/438] Loss: 0.4464(0.4755) Grad: 1.0891  LR: 0.000075  Elapsed: 12m 0s (remain 0m 15s) Max mem: 2963 MB
# Epoch: [2/5][429/438] Loss: 0.4768(0.4755) Grad: 1.2325  LR: 0.000075  Elapsed: 12m 1s (remain 0m 13s) Max mem: 2963 MB
# Epoch: [2/5][430/438] Loss: 0.4632(0.4755) Grad: 1.2122  LR: 0.000075  Elapsed: 12m 3s (remain 0m 11s) Max mem: 2963 MB
# Epoch: [2/5][431/438] Loss: 0.4703(0.4755) Grad: 1.2977  LR: 0.000075  Elapsed: 12m 5s (remain 0m 10s) Max mem: 2963 MB
# Epoch: [2/5][432/438] Loss: 0.4653(0.4755) Grad: 1.0957  LR: 0.000075  Elapsed: 12m 7s (remain 0m 8s) Max mem: 2963 MB
# Epoch: [2/5][433/438] Loss: 0.4633(0.4754) Grad: 0.8847  LR: 0.000075  Elapsed: 12m 9s (remain 0m 6s) Max mem: 2963 MB
# Epoch: [2/5][434/438] Loss: 0.4527(0.4754) Grad: 0.9044  LR: 0.000075  Elapsed: 12m 11s (remain 0m 5s) Max mem: 2963 MB
# Epoch: [2/5][435/438] Loss: 0.4742(0.4754) Grad: 0.9306  LR: 0.000075  Elapsed: 12m 13s (remain 0m 3s) Max mem: 2963 MB
# Epoch: [2/5][436/438] Loss: 0.4606(0.4753) Grad: 1.5779  LR: 0.000075  Elapsed: 12m 14s (remain 0m 1s) Max mem: 2963 MB
# Epoch: [2/5][437/438] Loss: 0.4890(0.4754) Grad: 1.5563  LR: 0.000075  Elapsed: 12m 15s (remain 0m 0s) Max mem: 2963 MB
# EVAL: [0/55] Data 1.325 (1.325) Elapsed 0m 4s (remain 3m 41s) Loss: 0.4401(0.4401)
# EVAL: [1/55] Data 0.013 (0.669) Elapsed 0m 6s (remain 2m 51s) Loss: 0.4670(0.4535)
# EVAL: [2/55] Data 0.014 (0.451) Elapsed 0m 8s (remain 2m 32s) Loss: 0.4601(0.4557)
# EVAL: [3/55] Data 0.011 (0.341) Elapsed 0m 11s (remain 2m 22s) Loss: 0.4811(0.4621)
# EVAL: [4/55] Data 0.013 (0.275) Elapsed 0m 13s (remain 2m 16s) Loss: 0.4568(0.4610)
# EVAL: [5/55] Data 0.012 (0.231) Elapsed 0m 16s (remain 2m 15s) Loss: 0.4653(0.4617)
# EVAL: [6/55] Data 0.011 (0.200) Elapsed 0m 19s (remain 2m 11s) Loss: 0.4875(0.4654)
# EVAL: [7/55] Data 0.014 (0.177) Elapsed 0m 21s (remain 2m 8s) Loss: 0.4697(0.4659)
# EVAL: [8/55] Data 0.014 (0.159) Elapsed 0m 24s (remain 2m 7s) Loss: 0.4704(0.4664)
# EVAL: [9/55] Data 0.023 (0.145) Elapsed 0m 28s (remain 2m 6s) Loss: 0.4443(0.4642)
# EVAL: [10/55] Data 0.014 (0.133) Elapsed 0m 30s (remain 2m 3s) Loss: 0.4589(0.4637)
# EVAL: [11/55] Data 0.010 (0.123) Elapsed 0m 33s (remain 1m 59s) Loss: 0.4581(0.4633)
# EVAL: [12/55] Data 0.011 (0.114) Elapsed 0m 36s (remain 1m 57s) Loss: 0.4719(0.4639)
# EVAL: [13/55] Data 0.011 (0.107) Elapsed 0m 38s (remain 1m 54s) Loss: 0.4569(0.4634)
# EVAL: [14/55] Data 0.011 (0.100) Elapsed 0m 41s (remain 1m 50s) Loss: 0.4688(0.4638)
# EVAL: [15/55] Data 0.009 (0.095) Elapsed 0m 43s (remain 1m 47s) Loss: 0.4740(0.4644)
# EVAL: [16/55] Data 0.011 (0.090) Elapsed 0m 46s (remain 1m 44s) Loss: 0.4713(0.4648)
# EVAL: [17/55] Data 0.015 (0.086) Elapsed 0m 49s (remain 1m 41s) Loss: 0.4737(0.4653)
# EVAL: [18/55] Data 0.013 (0.082) Elapsed 0m 51s (remain 1m 38s) Loss: 0.4721(0.4657)
# EVAL: [19/55] Data 0.013 (0.078) Elapsed 0m 54s (remain 1m 35s) Loss: 0.4507(0.4649)
# EVAL: [20/55] Data 0.013 (0.075) Elapsed 0m 57s (remain 1m 32s) Loss: 0.4570(0.4646)
# EVAL: [21/55] Data 0.016 (0.073) Elapsed 1m 0s (remain 1m 31s) Loss: 0.4644(0.4646)
# EVAL: [22/55] Data 0.015 (0.070) Elapsed 1m 4s (remain 1m 29s) Loss: 0.4738(0.4650)
# EVAL: [23/55] Data 0.017 (0.068) Elapsed 1m 6s (remain 1m 26s) Loss: 0.4702(0.4652)
# EVAL: [24/55] Data 0.014 (0.066) Elapsed 1m 9s (remain 1m 23s) Loss: 0.4574(0.4649)
# EVAL: [25/55] Data 0.019 (0.064) Elapsed 1m 12s (remain 1m 20s) Loss: 0.4763(0.4653)
# EVAL: [26/55] Data 0.015 (0.062) Elapsed 1m 14s (remain 1m 17s) Loss: 0.4544(0.4649)
# EVAL: [27/55] Data 0.013 (0.060) Elapsed 1m 17s (remain 1m 15s) Loss: 0.4718(0.4651)
# EVAL: [28/55] Data 0.014 (0.059) Elapsed 1m 20s (remain 1m 12s) Loss: 0.4699(0.4653)
# EVAL: [29/55] Data 0.012 (0.057) Elapsed 1m 24s (remain 1m 10s) Loss: 0.4621(0.4652)
# EVAL: [30/55] Data 0.015 (0.056) Elapsed 1m 27s (remain 1m 7s) Loss: 0.4679(0.4653)
# EVAL: [31/55] Data 0.013 (0.054) Elapsed 1m 30s (remain 1m 4s) Loss: 0.4801(0.4657)
# EVAL: [32/55] Data 0.014 (0.053) Elapsed 1m 32s (remain 1m 1s) Loss: 0.4669(0.4658)
# EVAL: [33/55] Data 0.014 (0.052) Elapsed 1m 34s (remain 0m 58s) Loss: 0.4739(0.4660)
# EVAL: [34/55] Data 0.014 (0.051) Elapsed 1m 37s (remain 0m 55s) Loss: 0.4684(0.4661)
# EVAL: [35/55] Data 0.014 (0.050) Elapsed 1m 39s (remain 0m 52s) Loss: 0.4816(0.4665)
# EVAL: [36/55] Data 0.014 (0.049) Elapsed 1m 41s (remain 0m 49s) Loss: 0.4616(0.4664)
# EVAL: [37/55] Data 0.014 (0.048) Elapsed 1m 44s (remain 0m 46s) Loss: 0.4682(0.4664)
# EVAL: [38/55] Data 0.013 (0.047) Elapsed 1m 46s (remain 0m 43s) Loss: 0.4564(0.4662)
# EVAL: [39/55] Data 0.014 (0.046) Elapsed 1m 48s (remain 0m 40s) Loss: 0.4535(0.4659)
# EVAL: [40/55] Data 0.014 (0.046) Elapsed 1m 51s (remain 0m 37s) Loss: 0.4653(0.4658)
# EVAL: [41/55] Data 0.013 (0.045) Elapsed 1m 53s (remain 0m 35s) Loss: 0.4827(0.4662)
# EVAL: [42/55] Data 0.014 (0.044) Elapsed 1m 55s (remain 0m 32s) Loss: 0.4637(0.4662)
# EVAL: [43/55] Data 0.015 (0.043) Elapsed 1m 58s (remain 0m 29s) Loss: 0.4482(0.4658)
# EVAL: [44/55] Data 0.013 (0.043) Elapsed 2m 0s (remain 0m 26s) Loss: 0.4800(0.4661)
# EVAL: [45/55] Data 0.014 (0.042) Elapsed 2m 3s (remain 0m 24s) Loss: 0.4581(0.4659)
# EVAL: [46/55] Data 0.015 (0.042) Elapsed 2m 5s (remain 0m 21s) Loss: 0.4523(0.4656)
# EVAL: [47/55] Data 0.020 (0.041) Elapsed 2m 8s (remain 0m 18s) Loss: 0.4523(0.4654)
# EVAL: [48/55] Data 0.017 (0.041) Elapsed 2m 11s (remain 0m 16s) Loss: 0.4779(0.4656)
# EVAL: [49/55] Data 0.013 (0.040) Elapsed 2m 13s (remain 0m 13s) Loss: 0.4962(0.4662)
# EVAL: [50/55] Data 0.015 (0.040) Elapsed 2m 16s (remain 0m 10s) Loss: 0.4842(0.4666)
# EVAL: [51/55] Data 0.015 (0.039) Elapsed 2m 18s (remain 0m 7s) Loss: 0.4689(0.4666)
# EVAL: [52/55] Data 0.011 (0.039) Elapsed 2m 20s (remain 0m 5s) Loss: 0.4681(0.4666)
# EVAL: [53/55] Data 0.014 (0.038) Elapsed 2m 22s (remain 0m 2s) Loss: 0.4660(0.4666)
# Epoch 2 - avg_train_loss: 0.4754  avg_val_loss: 0.4664  time: 880s
# Epoch 2 - Score: 0.8475
# Epoch 2 - Save Best Score: 0.8475 Model
# Epoch 2 - Save Best Loss: 0.4664 Model
# EVAL: [54/55] Data 0.010 (0.038) Elapsed 2m 24s (remain 0m 0s) Loss: 0.4487(0.4664)
# C:\Users\heinz\anaconda3\lib\site-packages\torch\cuda\nccl.py:16: UserWarning: PyTorch is not compiled with NCCL support
#   warnings.warn('PyTorch is not compiled with NCCL support')
# Epoch: [3/5][0/438] Loss: 0.4582(0.4582) Grad: 0.8251  LR: 0.000025  Elapsed: 0m 3s (remain 27m 38s) Max mem: 2963 MB
# Epoch: [3/5][1/438] Loss: 0.4700(0.4641) Grad: 1.0306  LR: 0.000025  Elapsed: 0m 5s (remain 20m 28s) Max mem: 2963 MB
# Epoch: [3/5][2/438] Loss: 0.4876(0.4719) Grad: 1.1827  LR: 0.000025  Elapsed: 0m 7s (remain 17m 56s) Max mem: 2963 MB
# Epoch: [3/5][3/438] Loss: 0.4497(0.4663) Grad: 0.9069  LR: 0.000025  Elapsed: 0m 9s (remain 16m 38s) Max mem: 2963 MB
# Epoch: [3/5][4/438] Loss: 0.4488(0.4628) Grad: 0.9486  LR: 0.000025  Elapsed: 0m 10s (remain 15m 51s) Max mem: 2963 MB
# Epoch: [3/5][5/438] Loss: 0.4603(0.4624) Grad: 0.9317  LR: 0.000025  Elapsed: 0m 12s (remain 15m 16s) Max mem: 2963 MB
# Epoch: [3/5][6/438] Loss: 0.4530(0.4611) Grad: 0.9730  LR: 0.000025  Elapsed: 0m 14s (remain 14m 53s) Max mem: 2963 MB
# Epoch: [3/5][7/438] Loss: 0.4529(0.4600) Grad: 0.7562  LR: 0.000025  Elapsed: 0m 16s (remain 14m 34s) Max mem: 2963 MB
# Epoch: [3/5][8/438] Loss: 0.4516(0.4591) Grad: 0.9232  LR: 0.000025  Elapsed: 0m 18s (remain 14m 24s) Max mem: 2963 MB
# Epoch: [3/5][9/438] Loss: 0.4828(0.4615) Grad: 1.0795  LR: 0.000025  Elapsed: 0m 19s (remain 14m 15s) Max mem: 2963 MB
# Epoch: [3/5][10/438] Loss: 0.4665(0.4619) Grad: 0.8275  LR: 0.000025  Elapsed: 0m 21s (remain 14m 8s) Max mem: 2963 MB
# Epoch: [3/5][11/438] Loss: 0.4637(0.4621) Grad: 0.8008  LR: 0.000025  Elapsed: 0m 23s (remain 13m 57s) Max mem: 2963 MB
# Epoch: [3/5][12/438] Loss: 0.4641(0.4622) Grad: 0.8432  LR: 0.000025  Elapsed: 0m 25s (remain 14m 2s) Max mem: 2963 MB
# Epoch: [3/5][13/438] Loss: 0.4528(0.4616) Grad: 0.9649  LR: 0.000025  Elapsed: 0m 27s (remain 14m 6s) Max mem: 2963 MB
# Epoch: [3/5][14/438] Loss: 0.4443(0.4604) Grad: 0.8175  LR: 0.000025  Elapsed: 0m 29s (remain 14m 1s) Max mem: 2963 MB
# Epoch: [3/5][15/438] Loss: 0.4690(0.4610) Grad: 0.9495  LR: 0.000025  Elapsed: 0m 31s (remain 13m 52s) Max mem: 2963 MB
# Epoch: [3/5][16/438] Loss: 0.4504(0.4603) Grad: 0.8898  LR: 0.000025  Elapsed: 0m 33s (remain 13m 45s) Max mem: 2963 MB
# Epoch: [3/5][17/438] Loss: 0.4592(0.4603) Grad: 1.2335  LR: 0.000025  Elapsed: 0m 35s (remain 13m 39s) Max mem: 2963 MB
# Epoch: [3/5][18/438] Loss: 0.4529(0.4599) Grad: 1.0310  LR: 0.000025  Elapsed: 0m 36s (remain 13m 31s) Max mem: 2963 MB
# Epoch: [3/5][19/438] Loss: 0.4683(0.4603) Grad: 0.9902  LR: 0.000025  Elapsed: 0m 38s (remain 13m 26s) Max mem: 2963 MB
# Epoch: [3/5][20/438] Loss: 0.4694(0.4607) Grad: 0.9858  LR: 0.000025  Elapsed: 0m 40s (remain 13m 23s) Max mem: 2963 MB
# Epoch: [3/5][21/438] Loss: 0.4759(0.4614) Grad: 1.0093  LR: 0.000025  Elapsed: 0m 42s (remain 13m 18s) Max mem: 2963 MB
# Epoch: [3/5][22/438] Loss: 0.4316(0.4601) Grad: 1.1853  LR: 0.000025  Elapsed: 0m 44s (remain 13m 14s) Max mem: 2963 MB
# Epoch: [3/5][23/438] Loss: 0.4442(0.4595) Grad: 1.1722  LR: 0.000025  Elapsed: 0m 45s (remain 13m 12s) Max mem: 2963 MB
# Epoch: [3/5][24/438] Loss: 0.4736(0.4600) Grad: 0.8173  LR: 0.000025  Elapsed: 0m 47s (remain 13m 6s) Max mem: 2963 MB
# Epoch: [3/5][25/438] Loss: 0.4683(0.4604) Grad: 1.5865  LR: 0.000025  Elapsed: 0m 49s (remain 13m 1s) Max mem: 2963 MB
# Epoch: [3/5][26/438] Loss: 0.4502(0.4600) Grad: 0.8545  LR: 0.000025  Elapsed: 0m 51s (remain 12m 56s) Max mem: 2963 MB
# Epoch: [3/5][27/438] Loss: 0.4680(0.4603) Grad: 1.1185  LR: 0.000025  Elapsed: 0m 52s (remain 12m 51s) Max mem: 2963 MB

# %% [markdown]
# ## Inference

# %%
states = []
for fold  in CFG.trn_fold:
    states.append(torch.load(os.path.join(SAVEDIR, f'{CFG.model_name}_fold{fold}_best_score.pth')))

# %%
gcs_paths = []
all_files = []
path = "./data1/test/"
n_trial = 0
#print(j)
for dirname, _, filenames in os.walk(path):
    for filename in filenames:
        #print(filename)
        #print(os.path.join(dirname, filename))
        gcs_path = os.path.join(dirname, filename)
        gcs_paths.append(gcs_path)
        print(gcs_path)
        all_files.extend(np.sort(np.array(tf.io.gfile.glob(gcs_path))))
    
print("test_files: ", len(all_files))
all_files = np.array(all_files)
# Out:
# gs://kds-3af0f2c792ef9e6f5d3c87bb80c99a263fc9707106cd595aaf02e3eb
# gs://kds-9eb3135b732342c0aec8339381fec9fd19f8a7ad94ca9c31ad51fe2b
# test_files:  10

# %%
model= CNN1d()
model.to(device)

wave_ids = []
probs_all = []

for fold, state in enumerate(states):
    tqdm.write(f"\n\nFold{fold}")
    
    model.load_state_dict(state['model'])
    model.eval()
    probs = []

    test_loader = TFRecordDataLoader(all_files, batch_size=CFG.val_batch_size, 
                                     shuffle=False, labeled=False)

    for i, d in tqdm(enumerate(test_loader), total=len(test_loader)):
        x = bandpass(d[0], **CFG.bandpass_params)
        x = torch.from_numpy(x).to(device)

        with torch.no_grad():
            y_preds = model(x)
        preds = y_preds.sigmoid().to('cpu').numpy()
        probs.append(preds)

        if fold==0: # same test loader, no need to do this the second time
            wave_ids.append(d[1].astype('U13'))

    probs = np.concatenate(probs)
    probs_all.append(probs)

probs_avg = np.asarray(probs_all).mean(axis=0).flatten()
wave_ids = np.concatenate(wave_ids)
# Out:
#   0%|          | 0/2250 [00:00<?, ?it/s]
# Fold0
# 2260it [06:43,  5.60it/s]
#   0%|          | 0/2250 [00:00<?, ?it/s]
# Fold1
# 2260it [06:40,  5.64it/s]
#   0%|          | 0/2250 [00:00<?, ?it/s]
# Fold2
# 2260it [06:28,  5.82it/s]
#   0%|          | 0/2250 [00:00<?, ?it/s]
# Fold3
# 2260it [06:31,  5.77it/s]

# %%
test_df = pd.DataFrame({'id': wave_ids, 'target': probs_avg})
# Save test dataframe to disk
folds = '_'.join([str(s) for s in CFG.trn_fold])
test_df.to_csv(f'{CFG.model_name}_folds_{folds}.csv', index = False)
